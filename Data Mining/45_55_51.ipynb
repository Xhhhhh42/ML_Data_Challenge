# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import time
import datetime
from datetime import timedelta
import scipy.stats as stats

# %%
ID_55_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_055_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_45_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_045_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_51_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_051_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_52_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_052_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
ID_51_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_051_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
Daten_1=ID_55_2020
Daten_2=ID_45_2020


Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-09-21 20:58:00')&(Daten_1['CreateDateTime']<'2020-09-22 00:25:00')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2020-09-21 20:58:00')&(Daten_2['CreateDateTime']<'2020-09-22 00:25:00')]


fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_55_2020_', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_45_2020', color=col2, fontsize=16)
ax2.plot(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
#plt.ylim((-1,10))

# %%
Daten_1=ID_55_2020
Daten_2=ID_45_2020


Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-09-22 13:58:00')&(Daten_1['CreateDateTime']<'2020-09-22 16:25:00')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2020-09-22 13:58:00')&(Daten_2['CreateDateTime']<'2020-09-22 16:25:00')]


fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_55_2020_', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_45_2020', color=col2, fontsize=16)
ax2.plot(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
#plt.ylim((-1,10))

# %%
Daten_1=ID_51_2020
Daten_2=ID_45_2020
Daten_3=ID_52_2020


Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-09-22 13:58:00')&(Daten_1['CreateDateTime']<'2020-09-22 16:25:00')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2020-09-22 13:58:00')&(Daten_2['CreateDateTime']<'2020-09-22 16:25:00')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2020-09-22 13:58:00')&(Daten_3['CreateDateTime']<'2020-09-22 16:25:00')]


fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_51_2020', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_45_2020', color=col2, fontsize=16)
ax2.plot(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
#plt.ylim((-1,10))


ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('ID_52_2020', color=col3, fontsize=16)
ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))

# %%
Daten_1=ID_55_2020
Daten_2=ID_45_2020


Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-06-26 16:27:13')&(Daten_1['CreateDateTime']<'2020-06-26 16:52:41')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2020-06-26 16:27:13')&(Daten_2['CreateDateTime']<'2020-06-26 16:52:41')]


fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_55_2020_', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_45_2020', color=col2, fontsize=16)
ax2.plot(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
#plt.ylim((-1,10))

# %%
a_ID_45_2020=ID_45_2020[(ID_45_2020['CreateDateTime']>'2020-06-26 16:27:13')&(ID_45_2020['CreateDateTime']<'2020-06-26 16:52:41')]
a_ID_45_2020.plot('CreateDateTime','TagValue')
# Out:
# <AxesSubplot:xlabel='CreateDateTime'>

# %%
a_ID_55_2020=ID_55_2020[(ID_55_2020['CreateDateTime']>'2020-06-26 16:27:13')&(ID_55_2020['CreateDateTime']<'2020-06-26 16:52:41')]
a_ID_55_2020.plot('CreateDateTime','TagValue')
# Out:
# <AxesSubplot:xlabel='CreateDateTime'>

# %%
ID_51_2020.plot('CreateDateTime','TagValue')
# Out:
# <AxesSubplot:xlabel='CreateDateTime'>

# %%
ID_51_2020
# Out:
#                   CreateDateTime  TagValue  TagId
# 0        2020-02-06 13:05:56.982 -4.050903     51
# 1        2020-02-06 13:05:57.207 -2.314819     51
# 2        2020-02-06 13:05:57.411 -4.050903     51
# 3        2020-02-06 13:05:58.025 -2.314819     51
# 4        2020-02-06 13:05:58.230 -3.472168     51
# ...                          ...       ...    ...
# 41324351 2020-12-19 00:11:20.126  0.000000     51
# 41324352 2020-12-19 00:11:22.150 -1.157471     51
# 41324353 2020-12-19 00:11:22.370  0.000000     51
# 41324354 2020-12-19 00:11:22.580 -1.157471     51
# 41324355 2020-12-19 00:11:22.985  0.000000     51
#
# [41324356 rows x 3 columns]
