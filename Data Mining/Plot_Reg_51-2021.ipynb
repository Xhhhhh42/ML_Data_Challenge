# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import time
import datetime
from datetime import timedelta
import scipy.stats as stats
from sklearn import datasets, linear_model

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import matplotlib.dates as mdate

# %%
ID_51_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_051_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_85_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_085_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_86_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_086_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

ID_45_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_045_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_48_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_048_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

ID_25_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_025_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_48_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_048_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

ID_70_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_070_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_71_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_071_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
ID_51_2021=ID_51_2021[(ID_51_2021['CreateDateTime']>'2021-01-01 00:00:00')&(ID_51_2021['CreateDateTime']<'2021-03-01 00:00:00')]

# %%
ID_133_bis_138_2021=pd.read_csv("C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\ID_133_bis_138_2021.csv",parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_141_bis_146_2021=pd.read_csv("C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\ID_141_bis_146_2021.csv",parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_139_2021=pd.read_csv("C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\ID_139_140_2021.csv",parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_147_2021=pd.read_csv("C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\ID_147_148_2021.csv",parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_133_bis_138_2021.columns = ['CreateDateTime','TagValue_133_138']
ID_141_bis_146_2021.columns = ['CreateDateTime','TagValue_141_146']
ID_139_2021.columns = ['CreateDateTime','TagValue_139']
ID_147_2021.columns = ['CreateDateTime','TagValue_147']
ID_86_2021['SignalZeit_86']=ID_86_2021['CreateDateTime']
ID_86_2021['SignalZeit_86_back']=ID_86_2021['CreateDateTime']

#ID_85_2021['CreateDateTime']=ID_85_2021['CreateDateTime']+datetime.timedelta(seconds=0.5)
#ID_86_2021['CreateDateTime']=ID_86_2021['CreateDateTime']+datetime.timedelta(seconds=1)

ID_85_2021['SignalZeit_85']=ID_85_2021['CreateDateTime']
ID_85_2021['SignalZeit_85_back']=ID_85_2021['CreateDateTime']

ID_45_2021['CreateDateTime']=ID_45_2021['CreateDateTime']+datetime.timedelta(seconds=40)
ID_45_2021['SignalZeit_45']=ID_45_2021['CreateDateTime']
ID_45_2021['SignalZeit_45_back']=ID_45_2021['CreateDateTime']

#ID_48_2021['CreateDateTime']=ID_48_2021['CreateDateTime']+datetime.timedelta(seconds=45)
ID_48_2021['SignalZeit_48']=ID_48_2021['CreateDateTime']
ID_48_2021['SignalZeit_48_back']=ID_48_2021['CreateDateTime']

ID_133_bis_138_2021['SignalZeit_133']=ID_133_bis_138_2021['CreateDateTime']
ID_139_2021['SignalZeit_139']=ID_139_2021['CreateDateTime']
ID_141_bis_146_2021['SignalZeit_141']=ID_141_bis_146_2021['CreateDateTime']
ID_147_2021['SignalZeit_147']=ID_147_2021['CreateDateTime']

ID_133_bis_138_2021['SignalZeit_133_head']=ID_133_bis_138_2021['CreateDateTime']
ID_139_2021['SignalZeit_139_head']=ID_139_2021['CreateDateTime']

ID_141_bis_146_2021['SignalZeit_141_head']=ID_141_bis_146_2021['CreateDateTime']
ID_147_2021['SignalZeit_147_head']=ID_147_2021['CreateDateTime']


ID_51_2021.columns = ['CreateDateTime','TagValue_51','TagId']
ID_85_2021.columns = ['CreateDateTime','TagValue_85','TagId','SignalZeit_85','SignalZeit_85_back']
ID_86_2021.columns = ['CreateDateTime','TagValue_86','TagId','SignalZeit_86','SignalZeit_86_back']
ID_45_2021.columns = ['CreateDateTime','TagValue_45','TagId','SignalZeit_45','SignalZeit_45_back']
ID_48_2021.columns = ['CreateDateTime','TagValue_48','TagId','SignalZeit_48','SignalZeit_48_back']
ID_70_2021.columns = ['CreateDateTime','TagValue_70','TagId']
ID_71_2021.columns = ['CreateDateTime','TagValue_71','TagId']

ID_51_2021=ID_51_2021.drop(columns=['TagId'])
ID_85_2021=ID_85_2021.drop(columns=['TagId'])
ID_86_2021=ID_86_2021.drop(columns=['TagId'])
ID_45_2021=ID_45_2021.drop(columns=['TagId'])
ID_48_2021=ID_48_2021.drop(columns=['TagId'])
ID_70_2021=ID_70_2021.drop(columns=['TagId'])
ID_71_2021=ID_71_2021.drop(columns=['TagId'])


ID_51_all_2021=ID_51_2021.set_index('CreateDateTime').join(ID_85_2021.set_index('CreateDateTime'),how='outer')
ID_51_all_2021=ID_51_all_2021.join(ID_86_2021.set_index('CreateDateTime'),how='outer')
ID_51_all_2021=ID_51_all_2021.join(ID_45_2021.set_index('CreateDateTime'),how='outer')
ID_51_all_2021=ID_51_all_2021.join(ID_48_2021.set_index('CreateDateTime'),how='outer')
ID_51_all_2021=ID_51_all_2021.join(ID_70_2021.set_index('CreateDateTime'),how='outer')
ID_51_all_2021=ID_51_all_2021.join(ID_71_2021.set_index('CreateDateTime'),how='outer')
ID_51_all_2021=ID_51_all_2021.join(ID_133_bis_138_2021.set_index('CreateDateTime'),how='outer')
ID_51_all_2021=ID_51_all_2021.join(ID_141_bis_146_2021.set_index('CreateDateTime'),how='outer')
ID_51_all_2021=ID_51_all_2021.join(ID_139_2021.set_index('CreateDateTime'),how='outer')
ID_51_all_2021=ID_51_all_2021.join(ID_147_2021.set_index('CreateDateTime'),how='outer')

ID_51_all_2021=ID_51_all_2021.reset_index()

#######################################################################################################################################

ID_51_all_2021['SignalZeit_85']=ID_51_all_2021['SignalZeit_85'].fillna(method="ffill")
ID_51_all_2021['SignalZeit_85_back']=ID_51_all_2021['SignalZeit_85_back'].fillna(method="bfill")
ID_51_all_2021['SignalZeit_86']=ID_51_all_2021['SignalZeit_86'].fillna(method="ffill")
ID_51_all_2021['SignalZeit_86_back']=ID_51_all_2021['SignalZeit_86_back'].fillna(method="bfill")
ID_51_all_2021['SignalZeit_45']=ID_51_all_2021['SignalZeit_45'].fillna(method="ffill")
ID_51_all_2021['SignalZeit_45_back']=ID_51_all_2021['SignalZeit_45_back'].fillna(method="bfill")
ID_51_all_2021['SignalZeit_48']=ID_51_all_2021['SignalZeit_48'].fillna(method="ffill")
ID_51_all_2021['SignalZeit_48_back']=ID_51_all_2021['SignalZeit_48_back'].fillna(method="bfill")

ID_51_all_2021['SignalZeit_133']=ID_51_all_2021['SignalZeit_133'].fillna(method="ffill")
ID_51_all_2021['SignalZeit_139']=ID_51_all_2021['SignalZeit_139'].fillna(method="ffill")
ID_51_all_2021['SignalZeit_141']=ID_51_all_2021['SignalZeit_141'].fillna(method="ffill")
ID_51_all_2021['SignalZeit_147']=ID_51_all_2021['SignalZeit_147'].fillna(method="ffill")
ID_51_all_2021['SignalZeit_133_head']=ID_51_all_2021['SignalZeit_133_head'].fillna(method="ffill")
ID_51_all_2021['SignalZeit_139_head']=ID_51_all_2021['SignalZeit_139_head'].fillna(method="ffill")
ID_51_all_2021['SignalZeit_141_head']=ID_51_all_2021['SignalZeit_141_head'].fillna(method="ffill")
ID_51_all_2021['SignalZeit_147_head']=ID_51_all_2021['SignalZeit_147_head'].fillna(method="ffill")

ID_51_all_2021=ID_51_all_2021.dropna(subset=['SignalZeit_85_back'])
ID_51_all_2021=ID_51_all_2021.dropna(subset=['SignalZeit_86_back'])
ID_51_all_2021=ID_51_all_2021.dropna(subset=['SignalZeit_45_back'])
ID_51_all_2021=ID_51_all_2021.dropna(subset=['SignalZeit_48_back'])

#ID_51_all_2021['TagValue_45']=np.where((ID_51_all_2021['SignalZeit_85_back']-ID_51_all_2021['SignalZeit_45']).dt.total_seconds()>70,ID_51_all_2021['TagValue_45'],0)

ID_51_all_2021['SignalZeit_85']=(ID_51_all_2021['CreateDateTime']-ID_51_all_2021['SignalZeit_85']).dt.total_seconds()
ID_51_all_2021['SignalZeit_86']=(ID_51_all_2021['CreateDateTime']-ID_51_all_2021['SignalZeit_86']).dt.total_seconds()
ID_51_all_2021['SignalZeit_85_back']=(ID_51_all_2021['SignalZeit_85_back']-ID_51_all_2021['CreateDateTime']).dt.total_seconds()
ID_51_all_2021['SignalZeit_86_back']=(ID_51_all_2021['SignalZeit_86_back']-ID_51_all_2021['CreateDateTime']).dt.total_seconds()


ID_51_all_2021['SignalZeit_45']=(ID_51_all_2021['CreateDateTime']-ID_51_all_2021['SignalZeit_45']).dt.total_seconds()
ID_51_all_2021['SignalZeit_45_back']=(ID_51_all_2021['SignalZeit_45_back']-ID_51_all_2021['CreateDateTime']).dt.total_seconds()
ID_51_all_2021['SignalZeit_48']=(ID_51_all_2021['CreateDateTime']-ID_51_all_2021['SignalZeit_48']).dt.total_seconds()
ID_51_all_2021['SignalZeit_48_back']=(ID_51_all_2021['SignalZeit_48_back']-ID_51_all_2021['CreateDateTime']).dt.total_seconds()

ID_51_all_2021['SignalZeit_133']=(ID_51_all_2021['CreateDateTime']-ID_51_all_2021['SignalZeit_133']).dt.total_seconds()
ID_51_all_2021['SignalZeit_139']=(ID_51_all_2021['CreateDateTime']-ID_51_all_2021['SignalZeit_139']).dt.total_seconds()
ID_51_all_2021['SignalZeit_133_head']=(ID_51_all_2021['CreateDateTime']-ID_51_all_2021['SignalZeit_133_head']).dt.total_seconds()
ID_51_all_2021['SignalZeit_139_head']=(ID_51_all_2021['CreateDateTime']-ID_51_all_2021['SignalZeit_139_head']).dt.total_seconds()
ID_51_all_2021['SignalZeit_141']=(ID_51_all_2021['CreateDateTime']-ID_51_all_2021['SignalZeit_141']).dt.total_seconds()
ID_51_all_2021['SignalZeit_147']=(ID_51_all_2021['CreateDateTime']-ID_51_all_2021['SignalZeit_147']).dt.total_seconds()
ID_51_all_2021['SignalZeit_141_head']=(ID_51_all_2021['CreateDateTime']-ID_51_all_2021['SignalZeit_141_head']).dt.total_seconds()
ID_51_all_2021['SignalZeit_147_head']=(ID_51_all_2021['CreateDateTime']-ID_51_all_2021['SignalZeit_147_head']).dt.total_seconds()

ID_51_all_2021=ID_51_all_2021.fillna(method="ffill")
ID_51_all_2021
# Out:
#                   CreateDateTime  TagValue_51  TagValue_85  SignalZeit_85  \
# 0        2021-01-04 08:00:46.018          NaN          1.0          0.000
# 1        2021-01-04 08:00:46.228          NaN          1.0          0.210
# 2        2021-01-04 08:00:46.646     1.157349          1.0          0.628
# 3        2021-01-04 08:00:46.845     0.000000          1.0          0.827
# 4        2021-01-04 08:00:47.875    -0.578735          1.0          1.857
# ...                          ...          ...          ...            ...
# 15588601 2021-10-03 20:17:13.033  -461.226810          0.0        262.167
# 15588602 2021-10-03 20:17:23.070  -461.226810          0.0        272.204
# 15588603 2021-10-03 20:17:23.692  -461.226810          0.0        272.826
# 15588604 2021-10-03 20:17:31.253  -461.226810          0.0        280.387
# 15588605 2021-10-03 20:17:31.263  -461.226810          0.0        280.397
#
#           SignalZeit_85_back  TagValue_86  SignalZeit_86  SignalZeit_86_back  \
# ...

# %%
#ID_51_all_2021.plot('CreateDateTime','SignalZeit_45_back')

# %%
import sys
print(sys.getsizeof(ID_51_all_2021) / 1024 / 1024, 'MB')
# Out:
# 3449.0171508789062 MB

# %%
# x=range(0, 6, 2)
# list(x)
#del  ID_51_2021, ID_85_2021, ID_86_2021, ID_48_2021, ID_71_2021, ID_133_bis_138_2021, ID_141_bis_146_2021, ID_139_2021, ID_147_2021

# %%
print(datetime.datetime.now())

for  Sin_86 in [135]:


    # data=ID_51_all_2021
    # data=data.dropna()
    #data=ID_51_all_2021[(ID_51_all_2021['CreateDateTime']>'2021-01-17 08:30:00')&(ID_51_all_2021['CreateDateTime']<'2021-01-30 10:00:16')]
    data=ID_51_all_2021[(ID_51_all_2021['CreateDateTime']>'2021-01-01 00:00:00')&(ID_51_all_2021['CreateDateTime']<'2021-03-01 00:00:00')]
    data=data.dropna()
    #Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-04-01 07:05:00')&(Daten_1['CreateDateTime']<'2021-04-01 07:40:00')]
    #Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-09-05 09:55:00')&(Daten_1['CreateDateTime']<'2021-09-05 10:48:16')]
    #Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-08-06 04:20:00')&(Daten_1['CreateDateTime']<'2021-08-06 04:56:16')]
    #Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-08-10 10:30:00')&(Daten_1['CreateDateTime']<'2021-08-10 11:00:16')]
    #)&(Daten_1['CreateDateTime']<)]['CreateDateTime']>'2021-01-17 08:30:00')&(Daten_1['CreateDateTime']<'2021-01-17 09:00:16')]
    #2021-01-29 09:55:00')&(Daten_1['CreateDateTime']<'2021-01-29 11:26:16')]
    #Daten_1 = Daten_1[(Daten_1['CreateDateTime']>'2021-04-01 08:05:00')&(Daten_1['CreateDateTime']<'2021-04-01 08:40:00')]

    data['SignalZeit_133']=np.where(data['TagValue_133_138']==0,data['SignalZeit_133'],0)
    data['SignalZeit_139']=np.where(data['TagValue_139']==0,data['SignalZeit_139'],0)
    data['SignalZeit_133_head']=np.where(data['TagValue_133_138']==0,0,data['SignalZeit_133_head'])
    data['SignalZeit_139_head']=np.where(data['TagValue_139']==0,0,data['SignalZeit_139_head'])

    data['SignalZeit_141']=np.where(data['TagValue_141_146']==0,data['SignalZeit_141'],0)
    data['SignalZeit_147']=np.where(data['TagValue_147']==0,data['SignalZeit_147'],0)
    data['SignalZeit_141_head']=np.where(data['TagValue_141_146']==0,0,data['SignalZeit_141_head'])
    data['SignalZeit_147_head']=np.where(data['TagValue_147']==0,0,data['SignalZeit_147_head'])


    data['SignalZeit_133']=data['TagValue_85']*data['SignalZeit_133']
    data['SignalZeit_139']=data['TagValue_85']*data['SignalZeit_139']
    data['SignalZeit_133_head']=data['TagValue_85']*data['SignalZeit_133_head']
    data['SignalZeit_139_head']=data['TagValue_85']*data['SignalZeit_139_head']

    data['SignalZeit_141']=data['TagValue_86']*data['SignalZeit_141']
    data['SignalZeit_147']=data['TagValue_86']*data['SignalZeit_147']
    data['SignalZeit_141_head']=data['TagValue_86']*data['SignalZeit_141_head']
    data['SignalZeit_147_head']=data['TagValue_86']*data['SignalZeit_147_head']


    data['SignalZeit_85']=data['TagValue_85']*data['SignalZeit_85']
    data['SignalZeit_86']=data['TagValue_86']*data['SignalZeit_86']
    data['SignalZeit_45']=data['TagValue_85']*data['TagValue_45']*data['SignalZeit_45']
    data['SignalZeit_48']=data['TagValue_86']*data['TagValue_48']*data['SignalZeit_48']

    
    data['SignalZeit_45_back']=np.where((data['SignalZeit_85_back']-data['SignalZeit_45_back'])>80,data['SignalZeit_45_back'],0)
    data['SignalZeit_85_back']=np.where(((data['SignalZeit_85_back']<=50)&(data['TagValue_45']==0)),data['SignalZeit_85_back'],0)
    
    data['SignalZeit_85_back']=data['TagValue_85']*data['SignalZeit_85_back']
    data['SignalZeit_86_back']=data['TagValue_86']*data['SignalZeit_86_back']
    #data['SignalZeit_45_back']=data['TagValue_85']*data['TagValue_45']*data['SignalZeit_45_back']
    data['SignalZeit_45_back']=data['TagValue_85']*data['TagValue_45']*data['SignalZeit_45_back']
    data['SignalZeit_48_back']=data['TagValue_86']*data['TagValue_48']*data['SignalZeit_48_back']
#    data=data.drop(columns=['TagValue_85'])
#    data=data.drop(columns=['TagValue_86'])
#    data=data.drop(columns=['TagValue_45'])



#     data['SignalZeit_85']=np.where(data['TagValue_70']>0,data['SignalZeit_85'],0)
#     data['SignalZeit_85_back']=np.where(data['TagValue_70']>0,0,data['SignalZeit_85_back'])

    #data['SignalZeit_85_back']=np.where(((data['SignalZeit_85_back']<=60)&(data['TagValue_45']==0)),data['SignalZeit_85_back'],0)
    data['SignalZeit_85']=np.where(data['SignalZeit_85_back']>0,0,data['SignalZeit_85'])
    data['Signal_70_NOT']=np.where(((data['SignalZeit_85']>0)&(data['TagValue_70']==0)),1,0)
    data['Signal_71_NOT']=np.where(((data['SignalZeit_86']>0)&(data['TagValue_71']==0)),1,0)
    

    data['SignalZeit_85_0']=np.where(data['SignalZeit_85']>0,1,0)
    data['SignalZeit_85_back_0']=np.where(data['SignalZeit_85_back']>0,1,0)
    
    
    
    
    # data['SignalZeit_85']=data['SignalZeit_85']*np.where(data['TagValue_45']>0,0,1)
    # data['SignalZeit_85_back']=data['SignalZeit_85_back']*np.where(data['TagValue_45']>0,0,1)
    # data=data.drop(columns=['TagValue_45'])

    data['SignalZeit_86_back']=np.where(((data['SignalZeit_86_back']<=18)&(data['TagValue_48']==0)),data['SignalZeit_86_back'],0)
    data['SignalZeit_86']=np.where(data['SignalZeit_86_back']>0,0,data['SignalZeit_86'])
    #data['SignalZeit_86_back']=np.where(data['SignalZeit_86']==0,data['SignalZeit_86_back'],0)


    data['SignalZeit_45_back']=np.where(data['SignalZeit_45_back']<80,data['SignalZeit_45_back'],0)
    data['SignalZeit_45']=np.where(data['SignalZeit_45_back']==0,data['SignalZeit_45'],0)
    data['SignalZeit_48_back']=np.where(data['SignalZeit_48_back']<6,data['SignalZeit_48_back'],0)
    data['SignalZeit_48']=np.where(data['SignalZeit_48_back']==0,data['SignalZeit_48'],0)    
    
    #data['SignalZeit_45_back']=np.where(data['SignalZeit_45']==0,data['SignalZeit_45_back'],0)

    data['SignalZeit_133']=1-np.exp(-((data['SignalZeit_133'])/8))
    data['SignalZeit_139']=1-np.exp(-((data['SignalZeit_139'])/8))
    data['SignalZeit_133_0']=np.where(data['SignalZeit_133']>0,1,0)
    data['SignalZeit_139_0']=np.where(data['SignalZeit_139']>0,1,0)

    data['SignalZeit_141']=1-np.exp(-((data['SignalZeit_141'])/10))
    data['SignalZeit_147']=1-np.exp(-((data['SignalZeit_147'])/10))
    data['SignalZeit_141_0']=np.where(data['SignalZeit_141']>0,1,0)
    data['SignalZeit_147_0']=np.where(data['SignalZeit_147']>0,1,0)
    # *np.sin(data['SignalZeit_133']/400*2*np.pi+np.pi/2)
    # *np.sin(data['SignalZeit_141']/400*2*np.pi+np.pi/2)




    data['SignalZeit_85_e']=1-np.exp(-((data['SignalZeit_85'])/30))
    #  data['SignalZeit_85_e']=1-np.exp(-((data['SignalZeit_85'])/30))*np.sin(data['SignalZeit_85']/400*2*np.pi+np.pi/2)
    #data['SignalZeit_85']=np.where(data['SignalZeit_85']>=0,data['SignalZeit_85'],0)
    data['SignalZeit_86_e']=1-np.exp(-((data['SignalZeit_86'])/10))
    data['SignalZeit_45_e']=1-np.exp(-((data['SignalZeit_45'])/20))
    data['SignalZeit_48_e']=1-np.exp(-((data['SignalZeit_48'])/20))

    #data['SignalZeit_85_e']=1-np.exp(-((data['SignalZeit_85'])/40))*np.sin(data['SignalZeit_85']/400*2*np.pi+np.pi/2)

    data['SignalZeit_85_back_e']=1-np.exp(-((data['SignalZeit_85_back'])/30))
    data['SignalZeit_86_back_e']=1-np.exp(-((data['SignalZeit_86_back'])/20))
    data['SignalZeit_45_back_e']=1-np.exp(-((data['SignalZeit_45_back'])/20))
    data['SignalZeit_48_back_e']=1-np.exp(-((data['SignalZeit_48_back'])/20))







    data['SignalZeit_85_0']=np.where(data['SignalZeit_85']>0,1,0)
    data['SignalZeit_85_1_2']=np.sqrt(data['SignalZeit_85'])
    data['SignalZeit_45_0']=np.where(data['SignalZeit_45']>0,1,0) 
    data['SignalZeit_45_2']=data['SignalZeit_45']*data['SignalZeit_45']
    data['SignalZeit_45_3']=data['SignalZeit_45_2']*data['SignalZeit_45']
    data['SignalZeit_45_back_0']=np.where(data['SignalZeit_45_back']>0,1,0)
    data['SignalZeit_45_back_2']=data['SignalZeit_45_back']*data['SignalZeit_45_back']
    data['SignalZeit_45_back_3']=data['SignalZeit_45_back_2']*data['SignalZeit_45_back']   
    
    data['SignalZeit_48_0']=np.where(data['SignalZeit_48']>0,1,0)   
    data['SignalZeit_48_2']=data['SignalZeit_48']*data['SignalZeit_48']
    data['SignalZeit_48_3']=data['SignalZeit_48_2']*data['SignalZeit_48']
    data['SignalZeit_48_back_0']=np.where(data['SignalZeit_48_back']>0,1,0)
    data['SignalZeit_48_back_2']=data['SignalZeit_48_back']*data['SignalZeit_48_back']
    data['SignalZeit_48_back_3']=data['SignalZeit_48_back_2']*data['SignalZeit_48_back']   


    data['SignalZeit_85_back_0']=np.where(data['SignalZeit_85_back']>0,1,0)
    data['SignalZeit_85_back_2']=data['SignalZeit_85_back']*data['SignalZeit_85_back']
    data['SignalZeit_85_back_3']=data['SignalZeit_85_back']*data['SignalZeit_85_back']*data['SignalZeit_85_back']
    


    data['SignalZeit_86_0']=np.where(data['SignalZeit_86']>0,1,0)


    data['SignalZeit_86_back_0']=np.where(data['SignalZeit_86_back']>0,1,0)
    data['SignalZeit_86_back_2']=data['SignalZeit_86_back']*data['SignalZeit_86_back']
    data['SignalZeit_86_back_3']=data['SignalZeit_86_back']*data['SignalZeit_86_back']*data['SignalZeit_86_back']

    data['SignalZeit_85_back_e_2']=data['SignalZeit_85_back_e']*data['SignalZeit_85_back_e']
    data['SignalZeit_85_back_e_3']=data['SignalZeit_85_back_e_2']*data['SignalZeit_85_back_e']
    
    # data['SignalZeit_45_2']=data['SignalZeit_45']*data['SignalZeit_45']
    # data['SignalZeit_45_3']=data['SignalZeit_45_2']*data['SignalZeit_45']


    # data['SignalZeit_85_back']=np.where(data['TagValue_70']==0,data['SignalZeit_85_back'],0)
    # data['SignalZeit_85_back_e']=1-np.exp(-(data['SignalZeit_85_back']/15))
    # data['SignalZeit_85_back_0']=np.where(data['SignalZeit_85_back']>0,1,0)
    # data['SignalZeit_85_back_2']=data['SignalZeit_85_back']*data['SignalZeit_85_back']
    # data['SignalZeit_85_back_3']=data['SignalZeit_85_back']*data['SignalZeit_85_back']*data['SignalZeit_85_back']
    # data['SignalZeit_85_back_4']=data['SignalZeit_85_back']*data['SignalZeit_85_back']*data['SignalZeit_85_back']*data['SignalZeit_85_back']
    # data['SignalZeit_85_back_5']=data['SignalZeit_85_back']*data['SignalZeit_85_back_4']
    # data['SignalZeit_85_back_6']=data['SignalZeit_85_back']*data['SignalZeit_85_back_5']
    # data['SignalZeit_85_back_7']=data['SignalZeit_85_back']*data['SignalZeit_85_back_6']
    # data['SignalZeit_85_back_8']=data['SignalZeit_85_back']*data['SignalZeit_85_back_7']
    # data['SignalZeit_85_back_sqrt']=np.sqrt(data['SignalZeit_85_back'])

    #data=data.drop(columns=['TagValue_70'])

    #########################################################################################################################################################
    ##                                                                     Prognose                                                                       ##
    #########################################################################################################################################################


    data.shape
    # X = data[[ 'SignalZeit_85_0',
    #            'SignalZeit_85_back_0',
    #            'SignalZeit_86_0',
    #            'SignalZeit_86_back_0',
    #            'TagValue_133_138','TagValue_141_146',
    #          ]]
    #X = data[['SignalZeit_85_sqrt','SignalZeit_85','SignalZeit_45','SignalZeit_85_back','SignalZeit_85_back_e','SignalZeit_85_back_0','SignalZeit_85_back_2'
    #            ,'SignalZeit_85_back_3','SignalZeit_85_back_4','SignalZeit_85_back_5','SignalZeit_85_back_6','SignalZeit_85_back_7','SignalZeit_85_back_8']]

    X_test = data[[ 'SignalZeit_85_e',
               #'SignalZeit_85_0',
                # 'TagValue_85',
                #'TagValue_86',
               # 'SignalZeit_85_1_2',
               #'SignalZeit_85',
               #'SignalZeit_85_back_e',
               'SignalZeit_85_back','SignalZeit_85_back_2','SignalZeit_85_back_3','SignalZeit_85_back_0',
               'SignalZeit_86_e',
               #'SignalZeit_86',
               #'SignalZeit_86_0',
               #'SignalZeit_86_back_e',
               #'SignalZeit_86_back_0',
               'SignalZeit_86_back','SignalZeit_86_back_2','SignalZeit_86_back_3','SignalZeit_86_back_0',
               'SignalZeit_45_e',
               'SignalZeit_45_0',
               #'SignalZeit_45',
              
               #'SignalZeit_45',
               #'SignalZeit_45_back_e',
               'SignalZeit_45_back_0','SignalZeit_45_back','SignalZeit_45_back_2','SignalZeit_45_back_3',  
               #'SignalZeit_45_0',
               #'SignalZeit_45_2','SignalZeit_45_3',
              
               'SignalZeit_48_e',
               'SignalZeit_48_0',
               # 'SignalZeit_48',
               #'SignalZeit_48_back_e',
                'SignalZeit_48_back_0','SignalZeit_48_back','SignalZeit_48_back_2','SignalZeit_48_back_3', 
              #'SignalZeit_48_back','SignalZeit_48_back_2','SignalZeit_48_back_3',  
               # 'SignalZeit_48_2','SignalZeit_48_3',
              
               'SignalZeit_133',
               'SignalZeit_133_0',
               'SignalZeit_133_head',
               'SignalZeit_139',
               'SignalZeit_139_0',
               'SignalZeit_139_head',
               'SignalZeit_141',
               'SignalZeit_141_head',
               'SignalZeit_141_0',
               'SignalZeit_147','SignalZeit_147_head',
               'SignalZeit_147_0',
               'Signal_70_NOT','Signal_71_NOT',
  
             ]]
    #####################################



    y_test = data[['TagValue_51']]


    #X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
    # print (X_train.shape)
    # print (y_train.shape)
    # print (X_test.shape)
    # print (y_test.shape)


    linreg = LinearRegression()
    # linreg.fit(X_train, y_train)

#     print (linreg.intercept_)
#     print (linreg.coef_)
    linreg.intercept_=[-6.16241778]
    linreg.coef_=[-3.75047790e+02,  3.97549133e+00, -3.15801923e-01,  3.60777211e-03,
  -2.28975700e+02, -3.48191603e+02, -2.29181056e+00,  2.28144093e-01,
  -1.40927841e-02, -2.81488387e+02,  1.91285329e+02, -2.43947039e+01,
   6.65376893e+00, -8.84201262e-01,  7.47085784e-02, -4.77565461e-04,
   2.80664381e-13, -2.70006240e-13, -4.45256314e+00, -1.30836465e+01,
   4.03689030e+00, -4.15203724e-01, -1.66323315e+01, -1.01296715e+01,
  -6.91156911e+01, -1.84158878e+01, -8.31024341e+00, -5.03943977e+01,
  -3.33706348e+01,  4.54244052e-02,  9.37634714e+00, -2.60813328e+01,
  -4.61281552e+01, -9.19880400e-01, -7.17473592e+00, -2.37181673e+01]



    #模型拟合测试集
    y_pred = linreg.intercept_+np.dot(X_test,linreg.coef_) 
    from sklearn import metrics
    # 用scikit-learn计算MSE
#     print ("MSE:",metrics.mean_squared_error(y_test, y_pred))
    # 用scikit-learn计算RMSE
    print ("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred))," Sin_86:", Sin_86)

    #X = data[['SignalZeit_85_sqrt','SignalZeit_85','SignalZeit_45','SignalZeit_85_back','SignalZeit_85_back_e','SignalZeit_85_back_0','SignalZeit_85_back_2','SignalZeit_85_back_3']]
#    y = data[['TagValue_51']]


print(datetime.datetime.now())

# 2022-10-02 01:39:16.769582
# RMSE: 36.921794625145544  Sin_86: 135
# 2022-10-02 01:42:48.330034
# Out:
# 2022-10-16 21:30:17.561194
# RMSE: 35.83203874500246  Sin_86: 135
# 2022-10-16 21:30:41.495209

# %%
#data['TagValue_70']

# %%
print (linreg.intercept_)
print (linreg.coef_)
# Out:
# [-6.16241778]
# [-375.04779, 3.97549133, -0.315801923, 0.00360777211, -228.9757, -348.191603, -2.29181056, 0.228144093, -0.0140927841, -281.488387, 191.285329, -24.3947039, 6.65376893, -0.884201262, 0.0747085784, -0.000477565461, 2.80664381e-13, -2.7000624e-13, -4.45256314, -13.0836465, 4.0368903, -0.415203724, -16.6323315, -10.1296715, -69.1156911, -18.4158878, -8.31024341, -50.3943977, -33.3706348, 0.0454244052, 9.37634714, -26.0813328, -46.1281552, -0.9198804, -7.17473592, -23.7181673]

# %%
data['predicted']=linreg.intercept_+np.dot(X_test,linreg.coef_) 
data['Differenz']=data['predicted']-data['TagValue_51']
print('MAE',np.mean(np.abs(data['Differenz'])))
# MAE 18.55767105376567
# Out:
# MAE 16.247692387815796

# %%
data['predicted']=linreg.intercept_+np.dot(X_test,linreg.coef_) 

Daten_1=data

Daten_1 = Daten_1[(Daten_1['CreateDateTime']>'2021-02-09 08:30:00')&(Daten_1['CreateDateTime']<'2021-02-09 09:30:00')]
#data=ID_51_all_2021[(ID_51_all_2021['CreateDateTime']>'2021-08-28 12:05:00')&(ID_51_all_2021['CreateDateTime']<'2021-08-28 14:40:00')]


fig, ax = plt.subplots(figsize=(12, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'


ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
#ax.xaxis.set_major_formatter(mdate.DateFormatter('%H:%M'))
ax.set_ylabel('Gemessene Werte von Förderdruck [mbar]', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue_51, color=col1)
ax.xaxis.set_major_formatter(mdate.DateFormatter('%m-%d %H:%M'))
ax.tick_params(axis='y', labelcolor=col1)
plt.ylim((-500,20))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('Prognostizierte Werte von Förderdruck [mbar]', color=col2, fontsize=16)
ax2.plot(Daten_1.CreateDateTime, Daten_1.predicted, color=col2)
ax2.xaxis.set_major_formatter(mdate.DateFormatter('%m-%d %H:%M'))
ax2.tick_params(axis='y', labelcolor=col2)
plt.ylim((-500,20))



ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('45_Laufmeldung Vibrationssieb BB 8.1 [Bool]', color=col4, fontsize=16)
ax3.plot(Daten_1.CreateDateTime, Daten_1.TagValue_45, color=col4)
ax3.tick_params(axis='y', labelcolor=col4)
ax3.xaxis.set_major_formatter(mdate.DateFormatter('%m-%d %H:%M'))
ax3.spines["right"].set_position(("axes", 1.1))

# %%
# ID_25_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_025_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
# ID_45_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_025_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# ID_48_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_048_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
# ID_133_138_2021=pd.read_csv("C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\ID_141_bis_146_2021.csv",parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

#data['predicted']=linreg.intercept_+np.dot(X_test,linreg.coef_.T) 

Daten_1=data
#Daten_3=ID_45_2021
#Daten_4=ID_133_138_2021
Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-08-28 12:00:00')&(Daten_1['CreateDateTime']<'2021-08-28 14:00:00')]
#Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2021-01-29 10:45:00')&(Daten_3['CreateDateTime']<'2021-01-29 10:55:16')]
#Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2021-04-02 08:05:00')&(Daten_4['CreateDateTime']<'2021-04-02 8:40:00')]


fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('y_test', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue_51, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
plt.ylim((-500,100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('y_pred', color=col2, fontsize=16)
ax2.scatter(Daten_1.CreateDateTime, Daten_1.predicted, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
plt.ylim((-500,100))


# ax3 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax3.set_ylabel('ID_48_', color=col3, fontsize=16)
# ax3.scatter(Daten_3.CreateDateTime, Daten_3.TagValue, color=col3)
# ax3.tick_params(axis='y', labelcolor=col3)
# ax3.spines["right"].set_position(("axes", 1.1))

# ax4 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax4.set_ylabel('TagValue_45', color=col4, fontsize=16)
# ax4.plot(Daten_1.CreateDateTime, Daten_1.Signal_71_NOT, color=col4)
# ax4.tick_params(axis='y', labelcolor=col4)
# ax4.spines["right"].set_position(("axes", 1.2))

# ax5 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax5.set_ylabel('TagValue_45', color=col5, fontsize=16)
# ax5.plot(Daten_1.CreateDateTime, Daten_1.SignalZeit_147, color=col5)
# ax5.tick_params(axis='y', labelcolor=col5)
# ax5.spines["right"].set_position(("axes", 1.3))
# Out:
# (-500.0, 100.0)

# %%
Daten_1=data
Daten_3=ID_45_2021
#Daten_4=ID_133_138_2021
Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-01-29 10:20:00')&(Daten_1['CreateDateTime']<'2021-01-29 10:30:16')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2021-01-29 10:20:00')&(Daten_3['CreateDateTime']<'2021-01-29 10:30:16')]
#Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2021-04-02 08:05:00')&(Daten_4['CreateDateTime']<'2021-04-02 8:40:00')]


fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('y_test', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue_51, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
plt.ylim((-500,100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('y_pred', color=col2, fontsize=16)
ax2.scatter(Daten_1.CreateDateTime, Daten_1.predicted, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
plt.ylim((-500,100))


# ax3 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax3.set_ylabel('ID_48_', color=col3, fontsize=16)
# ax3.scatter(Daten_3.CreateDateTime, Daten_3.TagValue, color=col3)
# ax3.tick_params(axis='y', labelcolor=col3)
# ax3.spines["right"].set_position(("axes", 1.1))

# ax4 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax4.set_ylabel('TagValue_45', color=col4, fontsize=16)
# ax4.plot(Daten_1.CreateDateTime, Daten_1.Signal_71_NOT, color=col4)
# ax4.tick_params(axis='y', labelcolor=col4)
# ax4.spines["right"].set_position(("axes", 1.2))

# ax5 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax5.set_ylabel('TagValue_45', color=col5, fontsize=16)
# ax5.plot(Daten_1.CreateDateTime, Daten_1.SignalZeit_147, color=col5)
# ax5.tick_params(axis='y', labelcolor=col5)
# ax5.spines["right"].set_position(("axes", 1.3))
# Out:
# (-500.0, 100.0)

# %%
Daten_3
# Out:
#              CreateDateTime  TagValue  TagId
# 893 2021-01-24 09:57:51.536       1.0     25
# 894 2021-01-24 10:02:27.700       0.0     25

# %%
ID_25_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_025_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

ID_48_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_048_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
# ID_133_138_2021=pd.read_csv("C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\ID_141_bis_146_2021.csv",parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

#data['predicted']=linreg.intercept_+np.dot(X_test,linreg.coef_.T) 

Daten_1=data
Daten_3=ID_48_2021
#Daten_4=ID_133_138_2021
Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-01-17 07:30:00')&(Daten_1['CreateDateTime']<'2021-01-17 15:00:16')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2021-01-17 07:30:00')&(Daten_3['CreateDateTime']<'2021-01-17 15:00:16')]
#Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2021-04-02 08:05:00')&(Daten_4['CreateDateTime']<'2021-04-02 8:40:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('y_test', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue_51, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
plt.ylim((-500,100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('y_pred', color=col2, fontsize=16)
ax2.plot(Daten_1.CreateDateTime, Daten_1.predicted, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
plt.ylim((-500,100))


ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('ID_48_', color=col3, fontsize=16)
ax3.scatter(Daten_1.CreateDateTime, Daten_1.TagValue_86, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))

ax4 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax4.set_ylabel('TagValue_45', color=col4, fontsize=16)
ax4.plot(Daten_1.CreateDateTime, Daten_1.TagValue_48, color=col4)
ax4.tick_params(axis='y', labelcolor=col4)
ax4.spines["right"].set_position(("axes", 1.2))

# %%
Daten_1.TagValue_48
# Out:
# 2523275    0.0
# 2523276    0.0
# 2523277    0.0
# 2523278    0.0
# 2523279    0.0
#           ...
# 2604970    0.0
# 2604971    0.0
# 2604972    0.0
# 2604973    0.0
# 2604974    0.0
# Name: TagValue_26, Length: 81700, dtype: float64

# %%
Daten_1=data
Daten_3=ID_25_2021
#Daten_4=ID_133_138_2021
Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-08-06 13:50:00')&(Daten_1['CreateDateTime']<'2021-08-06 14:10:16')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2021-08-06 13:50:00')&(Daten_3['CreateDateTime']<'2021-08-06 14:10:16')]
#Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2021-04-02 08:05:00')&(Daten_4['CreateDateTime']<'2021-04-02 08:40:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('y_test', color=col1, fontsize=16)
ax.scatter(Daten_1.CreateDateTime, Daten_1.TagValue_51, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
plt.ylim((-500,100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('y_pred', color=col2, fontsize=16)
ax2.plot(Daten_1.CreateDateTime, Daten_1.predicted, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
plt.ylim((-500,100))


ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('ID_25_', color=col3, fontsize=16)
ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))

ax4 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax4.set_ylabel('TagValue_70', color=col4, fontsize=16)
ax4.plot(Daten_1.CreateDateTime, Daten_1.TagValue_86, color=col4)
ax4.tick_params(axis='y', labelcolor=col4)
ax4.spines["right"].set_position(("axes", 1.2))

# %%
Daten_1=data
Daten_3=ID_25_2021
#Daten_4=ID_133_138_2021
Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-08-06 10:08:00')&(Daten_1['CreateDateTime']<'2021-08-06 10:15:16')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2021-08-06 10:08:00')&(Daten_3['CreateDateTime']<'2021-08-06 10:15:16')]
#Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2021-04-02 08:05:00')&(Daten_4['CreateDateTime']<'2021-04-02 08:40:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('y_test', color=col1, fontsize=16)
ax.scatter(Daten_1.CreateDateTime, Daten_1.TagValue_51, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
plt.ylim((-500,100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('y_pred', color=col2, fontsize=16)
ax2.plot(Daten_1.CreateDateTime, Daten_1.predicted, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
plt.ylim((-500,100))


ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('ID_25_', color=col3, fontsize=16)
ax3.scatter(Daten_3.CreateDateTime, Daten_3.TagValue, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))

ax4 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax4.set_ylabel('TagValue_70', color=col4, fontsize=16)
ax4.plot(Daten_1.CreateDateTime, Daten_1.TagValue_86, color=col4)
ax4.tick_params(axis='y', labelcolor=col4)
ax4.spines["right"].set_position(("axes", 1.2))

# %%
Daten_3
# Out:
#              CreateDateTime  TagValue  TagId
# 534 2020-08-06 10:52:16.643       1.0     26
# 535 2020-08-06 11:00:00.660       0.0     26

# %%
ID_48_2021.plot('CreateDateTime','TagValue')
# Out:
# <AxesSubplot:xlabel='CreateDateTime'>

# %%
ID_45_2021
# Out:
#                CreateDateTime  TagValue_45           SignalZeit_45  \
# 0     2020-02-06 13:05:56.982          0.0 2020-02-06 13:05:56.982
# 1     2020-02-06 13:36:17.436          1.0 2020-02-06 13:36:17.436
# 2     2020-02-06 13:46:33.326          0.0 2020-02-06 13:46:33.326
# 3     2020-02-06 13:50:13.548          1.0 2020-02-06 13:50:13.548
# 4     2020-02-06 13:50:25.458          0.0 2020-02-06 13:50:25.458
# ...                       ...          ...                     ...
# 10916 2020-12-18 22:58:51.410          0.0 2020-12-18 22:58:51.410
# 10917 2020-12-18 23:12:38.205          1.0 2020-12-18 23:12:38.205
# 10918 2020-12-18 23:21:55.451          0.0 2020-12-18 23:21:55.451
# 10919 2020-12-18 23:58:01.634          1.0 2020-12-18 23:58:01.634
# 10920 2020-12-19 00:06:02.733          0.0 2020-12-19 00:06:02.733
#
#            SignalZeit_45_back
# 0     2020-02-06 13:05:56.982
# 1     2020-02-06 13:36:17.436
# 2     2020-02-06 13:46:33.326
# 3     2020-02-06 13:50:13.548
# ...

# %%
Daten_1=data
Daten_3=ID_25_2021
#Daten_4=ID_133_138_2021
Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-08-06 13:50:00')&(Daten_1['CreateDateTime']<'2021-08-06 14:20:16')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2021-08-06 13:50:00')&(Daten_3['CreateDateTime']<'2021-08-06 14:20:16')]
#Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2021-04-02 08:05:00')&(Daten_4['CreateDateTime']<'2021-04-02 08:40:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('y_test', color=col1, fontsize=16)
ax.scatter(Daten_1.CreateDateTime, Daten_1.TagValue_51, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
plt.ylim((-500,100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('y_pred', color=col2, fontsize=16)
ax2.scatter(Daten_1.CreateDateTime, Daten_1.predicted, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
plt.ylim((-500,100))


ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('ID_45_', color=col3, fontsize=16)
ax3.plot(Daten_1.CreateDateTime, Daten_1.TagValue_45, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))

ax4 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax4.set_ylabel('TagValue_25', color=col4, fontsize=16)
ax4.plot(Daten_3.CreateDateTime, Daten_3.TagValue, color=col4)
ax4.tick_params(axis='y', labelcolor=col4)
ax4.spines["right"].set_position(("axes", 1.2))

# %%
#Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-08-05 10:55:00')&(Daten_1['CreateDateTime']<'2021-08-05 14:48:16')]

Daten_1=data
Daten_3=ID_25_2021
#Daten_4=ID_133_138_2021
Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-08-05 13:20:00')&(Daten_1['CreateDateTime']<'2021-08-05 13:46:16')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2021-08-05 13:20:00')&(Daten_3['CreateDateTime']<'2021-08-05 13:46:16')]
#Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2021-04-02 08:05:00')&(Daten_4['CreateDateTime']<'2021-04-02 08:40:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('y_test', color=col1, fontsize=16)
ax.scatter(Daten_1.CreateDateTime, Daten_1.TagValue_51, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
plt.ylim((-500,100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('y_pred', color=col2, fontsize=16)
ax2.scatter(Daten_1.CreateDateTime, Daten_1.predicted, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
plt.ylim((-500,100))


ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('ID_45_', color=col3, fontsize=16)
ax3.plot(Daten_1.CreateDateTime, Daten_1.TagValue_70, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))

ax4 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax4.set_ylabel('TagValue_25', color=col4, fontsize=16)
ax4.plot(Daten_3.CreateDateTime, Daten_3.TagValue, color=col4)
ax4.tick_params(axis='y', labelcolor=col4)
ax4.spines["right"].set_position(("axes", 1.2))

# %%
ID_25_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_025_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
#Prognose

print(datetime.datetime.now())

for  Sin_86 in [135]:


    # data=ID_51_all_2021
    # data=data.dropna()
    data=ID_51_all_2021[(ID_51_all_2021['CreateDateTime']>'2021-09-05 09:30:00')&(ID_51_all_2021['CreateDateTime']<'2021-09-10 10:30:00')]
    data=data.dropna()
    #Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-04-01 07:05:00')&(Daten_1['CreateDateTime']<'2021-04-01 07:40:00')]
    #Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-09-05 09:55:00')&(Daten_1['CreateDateTime']<'2021-09-05 10:48:16')]

    data['SignalZeit_133']=np.where(data['TagValue_133_138']==0,data['SignalZeit_133'],0)
    data['SignalZeit_139']=np.where(data['TagValue_139']==0,data['SignalZeit_139'],0)
    data['SignalZeit_133_head']=np.where(data['TagValue_133_138']==0,0,data['SignalZeit_133_head'])
    data['SignalZeit_139_head']=np.where(data['TagValue_139']==0,0,data['SignalZeit_139_head'])

    data['SignalZeit_141']=np.where(data['TagValue_141_146']==0,data['SignalZeit_141'],0)
    data['SignalZeit_147']=np.where(data['TagValue_147']==0,data['SignalZeit_147'],0)
    data['SignalZeit_141_head']=np.where(data['TagValue_141_146']==0,0,data['SignalZeit_141_head'])
    data['SignalZeit_147_head']=np.where(data['TagValue_147']==0,0,data['SignalZeit_147_head'])


    data['SignalZeit_133']=data['TagValue_85']*data['SignalZeit_133']
    data['SignalZeit_139']=data['TagValue_85']*data['SignalZeit_139']
    data['SignalZeit_133_head']=data['TagValue_85']*data['SignalZeit_133_head']
    data['SignalZeit_139_head']=data['TagValue_85']*data['SignalZeit_139_head']

    data['SignalZeit_141']=data['TagValue_86']*data['SignalZeit_141']
    data['SignalZeit_147']=data['TagValue_86']*data['SignalZeit_147']
    data['SignalZeit_141_head']=data['TagValue_86']*data['SignalZeit_141_head']
    data['SignalZeit_147_head']=data['TagValue_86']*data['SignalZeit_147_head']


    data['SignalZeit_85']=data['TagValue_85']*data['SignalZeit_85']
    data['SignalZeit_86']=data['TagValue_86']*data['SignalZeit_86']
    data['SignalZeit_45']=data['TagValue_85']*data['TagValue_45']*data['SignalZeit_45']

    data['SignalZeit_85_back']=data['TagValue_85']*data['SignalZeit_85_back']
    data['SignalZeit_86_back']=data['TagValue_86']*data['SignalZeit_86_back']
    data['SignalZeit_45_back']=data['TagValue_85']*data['TagValue_45']*data['SignalZeit_45_back']

    data=data.drop(columns=['TagValue_85'])
    data=data.drop(columns=['TagValue_86'])
    data=data.drop(columns=['TagValue_45'])



#     data['SignalZeit_85']=np.where(data['TagValue_70']>0,data['SignalZeit_85'],0)
#     data['SignalZeit_85_back']=np.where(data['TagValue_70']>0,0,data['SignalZeit_85_back'])

    data['SignalZeit_85']=np.where(data['TagValue_70']>0,data['SignalZeit_85'],0)
    data['SignalZeit_85_back']=np.where(data['SignalZeit_85']==0,data['SignalZeit_85_back'],0)

    data['SignalZeit_86']=np.where(data['SignalZeit_86']<=data['SignalZeit_86_back'],data['SignalZeit_86'],0)
    data['SignalZeit_86_back']=np.where(data['SignalZeit_86']==0,data['SignalZeit_86_back'],0)

    data['SignalZeit_45']=np.where(data['SignalZeit_45']<=data['SignalZeit_45_back']*10,data['SignalZeit_45'],0)
    data['SignalZeit_45_back']=np.where(data['SignalZeit_45']==0,data['SignalZeit_45_back'],0)

    data['SignalZeit_133']=1-np.exp(-((data['SignalZeit_133'])/8))
    data['SignalZeit_139']=1-np.exp(-((data['SignalZeit_139'])/8))
    data['SignalZeit_133_0']=np.where(data['SignalZeit_133']>0,1,0)
    data['SignalZeit_139_0']=np.where(data['SignalZeit_139']>0,1,0)

    data['SignalZeit_141']=1-np.exp(-((data['SignalZeit_141'])/8))
    data['SignalZeit_147']=1-np.exp(-((data['SignalZeit_147'])/8))
    data['SignalZeit_141_0']=np.where(data['SignalZeit_141']>0,1,0)
    data['SignalZeit_147_0']=np.where(data['SignalZeit_147']>0,1,0)
    # *np.sin(data['SignalZeit_133']/400*2*np.pi+np.pi/2)
    # *np.sin(data['SignalZeit_141']/400*2*np.pi+np.pi/2)




    data['SignalZeit_85_e']=1-np.exp(-((data['SignalZeit_85'])/20))
    #  data['SignalZeit_85_e']=1-np.exp(-((data['SignalZeit_85'])/30))*np.sin(data['SignalZeit_85']/400*2*np.pi+np.pi/2)
    #data['SignalZeit_85']=np.where(data['SignalZeit_85']>=0,data['SignalZeit_85'],0)
    data['SignalZeit_86_e']=1-np.exp(-((data['SignalZeit_86'])/15))
    data['SignalZeit_45_e']=1-np.exp(-((data['SignalZeit_45'])/100))

    #data['SignalZeit_85_e']=1-np.exp(-((data['SignalZeit_85'])/40))*np.sin(data['SignalZeit_85']/400*2*np.pi+np.pi/2)

    data['SignalZeit_85_back_e']=1-np.exp(-((data['SignalZeit_85_back'])/30))
    data['SignalZeit_86_back_e']=1-np.exp(-((data['SignalZeit_86_back'])/15))
    data['SignalZeit_45_back_e']=1-np.exp(-((data['SignalZeit_45_back'])/50))







    data['SignalZeit_85_0']=np.where(data['SignalZeit_85']>0,1,0)
    data['SignalZeit_45_0']=np.where(data['SignalZeit_45']>0,1,0)
    data['SignalZeit_45_2']=data['SignalZeit_45']*data['SignalZeit_45']
    data['SignalZeit_45_3']=data['SignalZeit_45_2']*data['SignalZeit_45']


    data['SignalZeit_85_back_0']=np.where(data['SignalZeit_85_back']>0,1,0)
    data['SignalZeit_85_back_2']=data['SignalZeit_85_back']*data['SignalZeit_85_back']
    data['SignalZeit_85_back_3']=data['SignalZeit_85_back']*data['SignalZeit_85_back']*data['SignalZeit_85_back']


    data['SignalZeit_86_0']=np.where(data['SignalZeit_86']>0,1,0)


    data['SignalZeit_86_back_0']=np.where(data['SignalZeit_86_back']>0,1,0)
    data['SignalZeit_86_back_2']=data['SignalZeit_86_back']*data['SignalZeit_86_back']
    data['SignalZeit_86_back_3']=data['SignalZeit_86_back']*data['SignalZeit_86_back']*data['SignalZeit_86_back']

    data['SignalZeit_85_back_e_2']=data['SignalZeit_85_back_e']*data['SignalZeit_85_back_e']
    data['SignalZeit_85_back_e_3']=data['SignalZeit_85_back_e_2']*data['SignalZeit_85_back_e']
    
    data['SignalZeit_45_2']=data['SignalZeit_45']*data['SignalZeit_45']
    data['SignalZeit_45_3']=data['SignalZeit_45_2']*data['SignalZeit_45']


    # data['SignalZeit_85_back']=np.where(data['TagValue_70']==0,data['SignalZeit_85_back'],0)
    # data['SignalZeit_85_back_e']=1-np.exp(-(data['SignalZeit_85_back']/15))
    # data['SignalZeit_85_back_0']=np.where(data['SignalZeit_85_back']>0,1,0)
    # data['SignalZeit_85_back_2']=data['SignalZeit_85_back']*data['SignalZeit_85_back']
    # data['SignalZeit_85_back_3']=data['SignalZeit_85_back']*data['SignalZeit_85_back']*data['SignalZeit_85_back']
    # data['SignalZeit_85_back_4']=data['SignalZeit_85_back']*data['SignalZeit_85_back']*data['SignalZeit_85_back']*data['SignalZeit_85_back']
    # data['SignalZeit_85_back_5']=data['SignalZeit_85_back']*data['SignalZeit_85_back_4']
    # data['SignalZeit_85_back_6']=data['SignalZeit_85_back']*data['SignalZeit_85_back_5']
    # data['SignalZeit_85_back_7']=data['SignalZeit_85_back']*data['SignalZeit_85_back_6']
    # data['SignalZeit_85_back_8']=data['SignalZeit_85_back']*data['SignalZeit_85_back_7']
    # data['SignalZeit_85_back_sqrt']=np.sqrt(data['SignalZeit_85_back'])

    data=data.drop(columns=['TagValue_70'])

    #########################################################################################################################################################
    ##                                                                     Prognose                                                                      ##
    #########################################################################################################################################################


    data.shape
    # X = data[[ 'SignalZeit_85_0',
    #            'SignalZeit_85_back_0',
    #            'SignalZeit_86_0',
    #            'SignalZeit_86_back_0',
    #            'TagValue_133_138','TagValue_141_146',
    #          ]]
    #X = data[['SignalZeit_85_sqrt','SignalZeit_85','SignalZeit_45','SignalZeit_85_back','SignalZeit_85_back_e','SignalZeit_85_back_0','SignalZeit_85_back_2'
    #            ,'SignalZeit_85_back_3','SignalZeit_85_back_4','SignalZeit_85_back_5','SignalZeit_85_back_6','SignalZeit_85_back_7','SignalZeit_85_back_8']]

    X_test = data[[ 'SignalZeit_85_e','SignalZeit_85_0',
               'SignalZeit_85',
               'SignalZeit_85_back_e','SignalZeit_85_back_0',
               'SignalZeit_85_back','SignalZeit_85_back_2','SignalZeit_85_back_3',
               'SignalZeit_86_e','SignalZeit_86_0',
               'SignalZeit_86_back_e','SignalZeit_86_back_0',
               'SignalZeit_45_e',
               'SignalZeit_45',
               'SignalZeit_45_back_e',
               #'SignalZeit_45_0',
               'SignalZeit_45_2','SignalZeit_45_3',
               'SignalZeit_133','SignalZeit_133_head','SignalZeit_133_0',
               'SignalZeit_139','SignalZeit_139_head','SignalZeit_139_0',
               'SignalZeit_141','SignalZeit_141_head','SignalZeit_141_0',
               'SignalZeit_147','SignalZeit_147_head','SignalZeit_147_0',
             ]]
    #####################################



    y_test = data[['TagValue_51']]


#     X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
#     # print (X_train.shape)
#     # print (y_train.shape)
#     # print (X_test.shape)
#     # print (y_test.shape)


#     linreg = LinearRegression()
#     linreg.fit(X_train, y_train)

#     print (linreg.intercept_)
#     print (linreg.coef_)

    #模型拟合测试集
    y_pred = linreg.predict(X_test)
    from sklearn import metrics
    # 用scikit-learn计算MSE
#     print ("MSE:",metrics.mean_squared_error(y_test, y_pred))
    # 用scikit-learn计算RMSE
    print ("RMSE:",np.sqrt(metrics.mean_squared_error(y_test, y_pred))," Sin_86:", Sin_86)

    #X = data[['SignalZeit_85_sqrt','SignalZeit_85','SignalZeit_45','SignalZeit_85_back','SignalZeit_85_back_e','SignalZeit_85_back_0','SignalZeit_85_back_2','SignalZeit_85_back_3']]
#    y = data[['TagValue_51']]


print(datetime.datetime.now())

# 2022-10-02 01:39:16.769582
# RMSE: 36.921794625145544  Sin_86: 135
# 2022-10-02 01:42:48.330034
# Out:
# 2022-10-13 20:33:37.603404
# RMSE: 38.6818726383492  Sin_86: 135
# 2022-10-13 20:33:38.863696

# %%
#data['predicted']=y_pred
data['predicted']=linreg.intercept_+np.dot(X_test,linreg.coef_.T) 
data['Differenz']=data['predicted']-data['TagValue_51']
print('MAE',np.mean(np.abs(data['Differenz'])))
#MAE 18.560788433923207
# Out:
# MAE 21.851360441301615

# %%
# ID_85_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_086_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
# ID_133_138_2021=pd.read_csv("C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\ID_141_bis_146_2021.csv",parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

#data['predicted']=linreg.intercept_+np.dot(X_test,linreg.coef_.T) 

Daten_1=data
#Daten_3=ID_45_2021
#Daten_4=ID_133_138_2021
Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-08-05 10:55:00')&(Daten_1['CreateDateTime']<'2021-08-05 14:48:16')]
#Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2021-09-05 09:55:00')&(Daten_3['CreateDateTime']<'2021-09-05 10:48:16')]
#Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2021-04-02 08:05:00')&(Daten_4['CreateDateTime']<'2021-04-02 08:40:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('y_test', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue_51, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
plt.ylim((-500,100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('y_pred', color=col2, fontsize=16)
ax2.plot(Daten_1.CreateDateTime, Daten_1.predicted, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
plt.ylim((-500,100))


# ax3 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax3.set_ylabel('ID_45_Laufmeldung Vibrationssieb BB 8.1', color=col3, fontsize=16)
# ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue_45, color=col3)
# ax3.tick_params(axis='y', labelcolor=col3)
# ax3.spines["right"].set_position(("axes", 1.1))

# ax4 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax4.set_ylabel('TagValue_133_138', color=col4, fontsize=16)
# ax4.plot(Daten_4.CreateDateTime, Daten_4.TagValue, color=col4)
# ax4.tick_params(axis='y', labelcolor=col4)
# ax4.spines["right"].set_position(("axes", 1.2))
# Out:
# (-500.0, 100.0)

# %%
# ID_85_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_086_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
# ID_133_138_2021=pd.read_csv("C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\ID_141_bis_146_2021.csv",parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

data['predicted']=linreg.intercept_+np.dot(X_test,linreg.coef_.T) 

Daten_1=data
#Daten_3=ID_45_2021
#Daten_4=ID_133_138_2021
Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-09-05 09:55:00')&(Daten_1['CreateDateTime']<'2021-09-05 10:48:16')]
#Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2021-09-05 09:55:00')&(Daten_3['CreateDateTime']<'2021-09-05 10:48:16')]
#Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2021-04-02 08:05:00')&(Daten_4['CreateDateTime']<'2021-04-02 08:40:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('y_test', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue_51, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
plt.ylim((-500,100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('y_pred', color=col2, fontsize=16)
ax2.plot(Daten_1.CreateDateTime, Daten_1.predicted, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
plt.ylim((-500,100))


# ax3 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax3.set_ylabel('ID_45_Laufmeldung Vibrationssieb BB 8.1', color=col3, fontsize=16)
# ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue_45, color=col3)
# ax3.tick_params(axis='y', labelcolor=col3)
# ax3.spines["right"].set_position(("axes", 1.1))

# ax4 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax4.set_ylabel('TagValue_133_138', color=col4, fontsize=16)
# ax4.plot(Daten_4.CreateDateTime, Daten_4.TagValue, color=col4)
# ax4.tick_params(axis='y', labelcolor=col4)
# ax4.spines["right"].set_position(("axes", 1.2))
# Out:
# (-500.0, 100.0)

# %%
data['TagValue_51'].mean()
# Out:
# -288.43129450023054

# %%
print(sys.getsizeof(data) / 1024 / 1024, 'MB')
# Out:
# 2.2732696533203125 MB

# %%
print(sys.getsizeof(ID_51_all_2021) / 1024 / 1024, 'MB')
# Out:
# 8298.67936706543 MB

# %%
id(data)
# Out:
# 2383438619312

# %%
# del data, X,y,X_train, X_test, y_train, y_test

# %%
id(ID_51_all_2021)
# Out:
# 2379860926768

# %%
del X, y, ID_51_2021, ID_85_2021, X_train, X_test, y_train, y_test, ID_86_2021, ID_45_2021, ID_48_2021, ID_71_2021, ID_133_bis_138_2021, ID_141_bis_146_2021, ID_139_2021, ID_147_2021

# ID_70_2021

# %%
print(sys.getsizeof(data) / 1024 / 1024, 'MB')
data.drop(['SignalZeit_85_e','SignalZeit_85_0',
           'SignalZeit_85_back_e','SignalZeit_85_back_0','SignalZeit_85_back','SignalZeit_85_back_2','SignalZeit_85_back_3',
           'SignalZeit_86_e','SignalZeit_86_0',
           'SignalZeit_86_back_e','SignalZeit_86_back_0',
           'SignalZeit_45_e',
           'SignalZeit_45_back_e',
           'SignalZeit_133','SignalZeit_133_head','SignalZeit_133_0',
           'SignalZeit_139','SignalZeit_139_head','SignalZeit_139_0',
           'SignalZeit_141','SignalZeit_141_head','SignalZeit_141_0',
           'SignalZeit_147','SignalZeit_147_head','SignalZeit_147_0',
           'SignalZeit_85','SignalZeit_86','SignalZeit_86_back','SignalZeit_45','SignalZeit_45_back','TagValue_133_138',
           'TagValue_141_146','TagValue_139','TagValue_147','SignalZeit_86_back_2','SignalZeit_86_back_3','SignalZeit_85_back_e_2','SignalZeit_85_back_e_3'
          ],axis=1,inplace=True)
#df=df.loc[:,[‘name1’,‘name2’,‘name3’]]
print(sys.getsizeof(data) / 1024 / 1024, 'MB')
# Out:
# 13032.166759490967 MB
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1908/628450508.py in <module>
#       1 print(sys.getsizeof(data) / 1024 / 1024, 'MB')
# ----> 2 data.drop(['SignalZeit_85_e','SignalZeit_85_0',
#       3            'SignalZeit_85_back_e','SignalZeit_85_back_0','SignalZeit_85_back','SignalZeit_85_back_2','SignalZeit_85_back_3',
#       4            'SignalZeit_86_e','SignalZeit_86_0',
#       5            'SignalZeit_86_back_e','SignalZeit_86_back_0',
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data
# Out:
#                   CreateDateTime  TagValue_51  SignalZeit_85  \
# 22316824 2020-09-05 09:55:00.032    -2.893555            0.0
# 22316825 2020-09-05 09:55:00.237    -4.050903            0.0
# 22316826 2020-09-05 09:55:00.442    -2.893555            0.0
# 22316827 2020-09-05 09:55:00.642    -5.208374            0.0
# 22316828 2020-09-05 09:55:00.853    -2.893555            0.0
# ...                          ...          ...            ...
# 22324459 2020-09-05 10:26:15.331    -5.208374            0.0
# 22324460 2020-09-05 10:26:15.534    -5.208374            0.0
# 22324461 2020-09-05 10:26:15.545    -5.786987            0.0
# 22324462 2020-09-05 10:26:15.742    -4.050903            0.0
# 22324463 2020-09-05 10:26:15.947    -5.208374            0.0
#
#           SignalZeit_85_back  SignalZeit_86  SignalZeit_86_back  \
# 22316824                 0.0          0.000                 0.0
# 22316825                 0.0          0.000                 0.0
# ...

# %%
ID_70_2021
# Out:
#                 CreateDateTime  TagValue_70
# 0      2020-02-06 13:05:56.982     0.000000
# 1      2020-02-06 13:11:43.551     0.491333
# 2      2020-02-06 13:11:43.754     3.713989
# 3      2020-02-06 13:11:43.957     7.690430
# 4      2020-02-06 13:11:44.159    11.755370
# ...                        ...          ...
# 517667 2020-12-26 22:28:18.740     4.205322
# 517668 2020-12-26 22:28:18.949     0.729370
# 517669 2020-12-26 22:28:19.152     0.091553
# 517670 2020-12-26 22:28:19.358     0.012207
# 517671 2020-12-26 22:28:19.563     0.000000
#
# [517672 rows x 2 columns]

# %%
# ID_85_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_086_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
# ID_133_138_2021=pd.read_csv("C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\ID_141_bis_146_2021.csv",parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

data['predicted']=linreg.intercept_+np.dot(X,linreg.coef_.T) 

Daten_1=data
#Daten_3=ID_45_2021
#Daten_4=ID_133_138_2021
Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-09-05 09:55:00')&(Daten_1['CreateDateTime']<'2021-09-05 10:48:16')]
#Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2021-09-05 09:55:00')&(Daten_3['CreateDateTime']<'2021-09-05 10:48:16')]
#Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2021-04-02 08:05:00')&(Daten_4['CreateDateTime']<'2021-04-02 08:40:00')]

fig, ax = plt.subplots(figsize=(12, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('y_test', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue_51, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
plt.ylim((-500,100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('y_pred', color=col2, fontsize=16)
ax2.plot(Daten_1.CreateDateTime, Daten_1.predicted, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
plt.ylim((-500,100))


# ax3 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax3.set_ylabel('ID_45_Laufmeldung Vibrationssieb BB 8.1', color=col3, fontsize=16)
# ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue_45, color=col3)
# ax3.tick_params(axis='y', labelcolor=col3)
# ax3.spines["right"].set_position(("axes", 1.1))

# ax4 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax4.set_ylabel('TagValue_133_138', color=col4, fontsize=16)
# ax4.plot(Daten_4.CreateDateTime, Daten_4.TagValue, color=col4)
# ax4.tick_params(axis='y', labelcolor=col4)
# ax4.spines["right"].set_position(("axes", 1.2))

# %%
Daten_1=data
Daten_3=ID_45_2021
#Daten_4=ID_133_138_2021
Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-09-05 10:04:00')&(Daten_1['CreateDateTime']<'2021-09-05 10:10:16')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2021-09-05 10:04:00')&(Daten_3['CreateDateTime']<'2021-09-05 10:10:16')]
#Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2021-04-02 08:05:00')&(Daten_4['CreateDateTime']<'2021-04-02 08:40:00')]

fig, ax = plt.subplots(figsize=(12, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_51_2021_Druck_mbar', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue_51, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
plt.ylim((-500,100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_51_2021_Druck_predicted_mbar', color=col2, fontsize=16)
ax2.plot(Daten_1.CreateDateTime, Daten_1.predicted, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
plt.ylim((-500,100))


# ax3 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax3.set_ylabel('TagValue_85', color=col3, fontsize=16)
# ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue_45, color=col3)
# ax3.tick_params(axis='y', labelcolor=col3)
# ax3.spines["right"].set_position(("axes", 1.1))

# ax4 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax4.set_ylabel('TagValue_133_138', color=col4, fontsize=16)
# ax4.plot(Daten_4.CreateDateTime, Daten_4.TagValue, color=col4)
# ax4.tick_params(axis='y', labelcolor=col4)
# ax4.spines["right"].set_position(("axes", 1.2))
# Out:
# (-500.0, 100.0)

# %%
print(datetime.datetime.now())

for  Sin_86 in [135]:


    # data=ID_51_all_2021
    # data=data.dropna()
    data=ID_51_all_2021[(ID_51_all_2021['CreateDateTime']>'2021-10-01 00:00:00')&(ID_51_all_2021['CreateDateTime']<'2021-10-15 00:00:00')]
    data=data.dropna()
    #Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-04-01 07:05:00')&(Daten_1['CreateDateTime']<'2021-04-01 07:40:00')]
    #Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-09-05 09:55:00')&(Daten_1['CreateDateTime']<'2021-09-05 10:48:16')]

    data['SignalZeit_133']=np.where(data['TagValue_133_138']==0,data['SignalZeit_133'],0)
    data['SignalZeit_139']=np.where(data['TagValue_139']==0,data['SignalZeit_139'],0)
    data['SignalZeit_133_head']=np.where(data['TagValue_133_138']==0,0,data['SignalZeit_133_head'])
    data['SignalZeit_139_head']=np.where(data['TagValue_139']==0,0,data['SignalZeit_139_head'])

    data['SignalZeit_141']=np.where(data['TagValue_141_146']==0,data['SignalZeit_141'],0)
    data['SignalZeit_147']=np.where(data['TagValue_147']==0,data['SignalZeit_147'],0)
    data['SignalZeit_141_head']=np.where(data['TagValue_141_146']==0,0,data['SignalZeit_141_head'])
    data['SignalZeit_147_head']=np.where(data['TagValue_147']==0,0,data['SignalZeit_147_head'])


    data['SignalZeit_133']=data['TagValue_85']*data['SignalZeit_133']
    data['SignalZeit_139']=data['TagValue_85']*data['SignalZeit_139']
    data['SignalZeit_133_head']=data['TagValue_85']*data['SignalZeit_133_head']
    data['SignalZeit_139_head']=data['TagValue_85']*data['SignalZeit_139_head']

    data['SignalZeit_141']=data['TagValue_86']*data['SignalZeit_141']
    data['SignalZeit_147']=data['TagValue_86']*data['SignalZeit_147']
    data['SignalZeit_141_head']=data['TagValue_86']*data['SignalZeit_141_head']
    data['SignalZeit_147_head']=data['TagValue_86']*data['SignalZeit_147_head']


    data['SignalZeit_85']=data['TagValue_85']*data['SignalZeit_85']
    data['SignalZeit_86']=data['TagValue_86']*data['SignalZeit_86']
    data['SignalZeit_45']=data['TagValue_85']*data['TagValue_45']*data['SignalZeit_45']

    data['SignalZeit_85_back']=data['TagValue_85']*data['SignalZeit_85_back']
    data['SignalZeit_86_back']=data['TagValue_86']*data['SignalZeit_86_back']
    data['SignalZeit_45_back']=data['TagValue_85']*data['TagValue_45']*data['SignalZeit_45_back']

    data=data.drop(columns=['TagValue_85'])
    data=data.drop(columns=['TagValue_86'])
    data=data.drop(columns=['TagValue_45'])



#     data['SignalZeit_85']=np.where(data['TagValue_70']>0,data['SignalZeit_85'],0)
#     data['SignalZeit_85_back']=np.where(data['TagValue_70']>0,0,data['SignalZeit_85_back'])

    data['SignalZeit_85']=np.where(data['TagValue_70']>0,data['SignalZeit_85'],0)
    data['SignalZeit_85_back']=np.where(data['SignalZeit_85']==0,data['SignalZeit_85_back'],0)

    data['SignalZeit_86']=np.where(data['SignalZeit_86']<=data['SignalZeit_86_back'],data['SignalZeit_86'],0)
    data['SignalZeit_86_back']=np.where(data['SignalZeit_86']==0,data['SignalZeit_86_back'],0)

    data['SignalZeit_45']=np.where(data['SignalZeit_45']<=data['SignalZeit_45_back']*10,data['SignalZeit_45'],0)
    data['SignalZeit_45_back']=np.where(data['SignalZeit_45']==0,data['SignalZeit_45_back'],0)

    data['SignalZeit_133']=1-np.exp(-((data['SignalZeit_133'])/8))
    data['SignalZeit_139']=1-np.exp(-((data['SignalZeit_139'])/8))
    data['SignalZeit_133_0']=np.where(data['SignalZeit_133']>0,1,0)
    data['SignalZeit_139_0']=np.where(data['SignalZeit_139']>0,1,0)

    data['SignalZeit_141']=1-np.exp(-((data['SignalZeit_141'])/8))
    data['SignalZeit_147']=1-np.exp(-((data['SignalZeit_147'])/8))
    data['SignalZeit_141_0']=np.where(data['SignalZeit_141']>0,1,0)
    data['SignalZeit_147_0']=np.where(data['SignalZeit_147']>0,1,0)
    # *np.sin(data['SignalZeit_133']/400*2*np.pi+np.pi/2)
    # *np.sin(data['SignalZeit_141']/400*2*np.pi+np.pi/2)




    data['SignalZeit_85_e']=1-np.exp(-((data['SignalZeit_85'])/20))
    #  data['SignalZeit_85_e']=1-np.exp(-((data['SignalZeit_85'])/30))*np.sin(data['SignalZeit_85']/400*2*np.pi+np.pi/2)
    #data['SignalZeit_85']=np.where(data['SignalZeit_85']>=0,data['SignalZeit_85'],0)
    data['SignalZeit_86_e']=1-np.exp(-((data['SignalZeit_86'])/15))
    data['SignalZeit_45_e']=1-np.exp(-((data['SignalZeit_45'])/100))

    #data['SignalZeit_85_e']=1-np.exp(-((data['SignalZeit_85'])/40))*np.sin(data['SignalZeit_85']/400*2*np.pi+np.pi/2)

    data['SignalZeit_85_back_e']=1-np.exp(-((data['SignalZeit_85_back'])/30))
    data['SignalZeit_86_back_e']=1-np.exp(-((data['SignalZeit_86_back'])/15))
    data['SignalZeit_45_back_e']=1-np.exp(-((data['SignalZeit_45_back'])/50))







    data['SignalZeit_85_0']=np.where(data['SignalZeit_85']>0,1,0)
    data['SignalZeit_45_0']=np.where(data['SignalZeit_45']>0,1,0)
    data['SignalZeit_45_2']=data['SignalZeit_45']*data['SignalZeit_45']
    data['SignalZeit_45_3']=data['SignalZeit_45_2']*data['SignalZeit_45']


    data['SignalZeit_85_back_0']=np.where(data['SignalZeit_85_back']>0,1,0)
    data['SignalZeit_85_back_2']=data['SignalZeit_85_back']*data['SignalZeit_85_back']
    data['SignalZeit_85_back_3']=data['SignalZeit_85_back']*data['SignalZeit_85_back']*data['SignalZeit_85_back']


    data['SignalZeit_86_0']=np.where(data['SignalZeit_86']>0,1,0)


    data['SignalZeit_86_back_0']=np.where(data['SignalZeit_86_back']>0,1,0)
    data['SignalZeit_86_back_2']=data['SignalZeit_86_back']*data['SignalZeit_86_back']
    data['SignalZeit_86_back_3']=data['SignalZeit_86_back']*data['SignalZeit_86_back']*data['SignalZeit_86_back']

    data['SignalZeit_85_back_e_2']=data['SignalZeit_85_back_e']*data['SignalZeit_85_back_e']
    data['SignalZeit_85_back_e_3']=data['SignalZeit_85_back_e_2']*data['SignalZeit_85_back_e']
    
    data['SignalZeit_45_2']=data['SignalZeit_45']*data['SignalZeit_45']
    data['SignalZeit_45_3']=data['SignalZeit_45_2']*data['SignalZeit_45']


    # data['SignalZeit_85_back']=np.where(data['TagValue_70']==0,data['SignalZeit_85_back'],0)
    # data['SignalZeit_85_back_e']=1-np.exp(-(data['SignalZeit_85_back']/15))
    # data['SignalZeit_85_back_0']=np.where(data['SignalZeit_85_back']>0,1,0)
    # data['SignalZeit_85_back_2']=data['SignalZeit_85_back']*data['SignalZeit_85_back']
    # data['SignalZeit_85_back_3']=data['SignalZeit_85_back']*data['SignalZeit_85_back']*data['SignalZeit_85_back']
    # data['SignalZeit_85_back_4']=data['SignalZeit_85_back']*data['SignalZeit_85_back']*data['SignalZeit_85_back']*data['SignalZeit_85_back']
    # data['SignalZeit_85_back_5']=data['SignalZeit_85_back']*data['SignalZeit_85_back_4']
    # data['SignalZeit_85_back_6']=data['SignalZeit_85_back']*data['SignalZeit_85_back_5']
    # data['SignalZeit_85_back_7']=data['SignalZeit_85_back']*data['SignalZeit_85_back_6']
    # data['SignalZeit_85_back_8']=data['SignalZeit_85_back']*data['SignalZeit_85_back_7']
    # data['SignalZeit_85_back_sqrt']=np.sqrt(data['SignalZeit_85_back'])

    data=data.drop(columns=['TagValue_70'])

    #########################################################################################################################################################
    ##                                                                     Regression                                                                      ##
    #########################################################################################################################################################


    data.shape
    # X = data[[ 'SignalZeit_85_0',
    #            'SignalZeit_85_back_0',
    #            'SignalZeit_86_0',
    #            'SignalZeit_86_back_0',
    #            'TagValue_133_138','TagValue_141_146',
    #          ]]
    #X = data[['SignalZeit_85_sqrt','SignalZeit_85','SignalZeit_45','SignalZeit_85_back','SignalZeit_85_back_e','SignalZeit_85_back_0','SignalZeit_85_back_2'
    #            ,'SignalZeit_85_back_3','SignalZeit_85_back_4','SignalZeit_85_back_5','SignalZeit_85_back_6','SignalZeit_85_back_7','SignalZeit_85_back_8']]

    X = data[[ 'SignalZeit_85_e','SignalZeit_85_0',
               'SignalZeit_85',
               'SignalZeit_85_back_e','SignalZeit_85_back_0',
               'SignalZeit_85_back','SignalZeit_85_back_2','SignalZeit_85_back_3',
               'SignalZeit_86_e','SignalZeit_86_0',
               'SignalZeit_86_back_e','SignalZeit_86_back_0',
               'SignalZeit_45_e',
               'SignalZeit_45',
               'SignalZeit_45_back_e',
               'SignalZeit_45_0','SignalZeit_45_2','SignalZeit_45_3',
               'SignalZeit_133','SignalZeit_133_head','SignalZeit_133_0',
               'SignalZeit_139','SignalZeit_139_head','SignalZeit_139_0',
               'SignalZeit_141','SignalZeit_141_head','SignalZeit_141_0',
               'SignalZeit_147','SignalZeit_147_head','SignalZeit_147_0',
             ]]
    #####################################



    y = data[['TagValue_51']]


#     X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
#     # print (X_train.shape)
#     # print (y_train.shape)
#     # print (X_test.shape)
#     # print (y_test.shape)


#     linreg = LinearRegression()
#     linreg.fit(X_train, y_train)

#     print (linreg.intercept_)
#     print (linreg.coef_)

    #模型拟合测试集
    y_pred = linreg.predict(X)
    from sklearn import metrics
    # 用scikit-learn计算MSE
#     print ("MSE:",metrics.mean_squared_error(y_test, y_pred))
    # 用scikit-learn计算RMSE
    print ("RMSE:",np.sqrt(metrics.mean_squared_error(y, y_pred))," Sin_86:", Sin_86)

    #X = data[['SignalZeit_85_sqrt','SignalZeit_85','SignalZeit_45','SignalZeit_85_back','SignalZeit_85_back_e','SignalZeit_85_back_0','SignalZeit_85_back_2','SignalZeit_85_back_3']]
#    y = data[['TagValue_51']]


print(datetime.datetime.now())

# 2022-10-02 01:39:16.769582
# RMSE: 36.921794625145544  Sin_86: 135
# 2022-10-02 01:42:48.330034
# Out:
# 2022-10-13 02:23:38.275099
# RMSE: 38.98847597615995  Sin_86: 135
# 2022-10-13 02:23:43.473041

# %%
data['predicted']=linreg.intercept_+np.dot(X,linreg.coef_.T) 
data['Differenz']=data['predicted']-data['TagValue_51']
print('MAE',np.mean(np.abs(data['Differenz'])))
#MAE 18.560788433923207
# Out:
# MAE 23.233534556997586

# %%
# ID_85_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_086_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
# ID_133_138_2021=pd.read_csv("C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\ID_141_bis_146_2021.csv",parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

#data['predicted']=linreg.intercept_+np.dot(X,linreg.coef_.T) 

Daten_1=data
Daten_3=ID_45_2021
#Daten_4=ID_133_138_2021
Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-10-03 13:55:00')&(Daten_1['CreateDateTime']<'2021-10-03 15:46:16')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2021-10-03 13:55:00')&(Daten_3['CreateDateTime']<'2021-10-03 15:46:16')]
#Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2021-04-02 08:05:00')&(Daten_4['CreateDateTime']<'2021-04-02 08:40:00')]

fig, ax = plt.subplots(figsize=(12, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_51_2021_Druck_mbar', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue_51, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
plt.ylim((-500,100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_51_2021_Druck_predicted_mbar', color=col2, fontsize=16)
ax2.plot(Daten_1.CreateDateTime, Daten_1.predicted, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
plt.ylim((-500,100))


ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('ID_45_Laufmeldung Vibrationssieb BB 8.1', color=col3, fontsize=16)
ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue_45, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))

# ax4 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax4.set_ylabel('TagValue_133_138', color=col4, fontsize=16)
# ax4.plot(Daten_4.CreateDateTime, Daten_4.TagValue, color=col4)
# ax4.tick_params(axis='y', labelcolor=col4)
# ax4.spines["right"].set_position(("axes", 1.2))

# %%
ID_86_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_086_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_133_138_2021=pd.read_csv("C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\ID_141_bis_146_2021.csv",parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_71_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_073_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

#data['predicted']=linreg.intercept_+np.dot(X,linreg.coef_.T) 

Daten_1=data
Daten_3=ID_86_2021
Daten_4=ID_71_2021
Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-05-10 08:05:00')&(Daten_1['CreateDateTime']<'2021-05-20 10:40:00')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2021-05-10 08:05:00')&(Daten_3['CreateDateTime']<'2021-05-20 10:40:00')]
Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2021-05-10 08:05:00')&(Daten_4['CreateDateTime']<'2021-05-20 10:40:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_51_2021', color=col1, fontsize=16)
ax.scatter(Daten_1.CreateDateTime, Daten_1.TagValue_51, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
plt.ylim((-500,100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_51_predicted', color=col2, fontsize=16)
ax2.scatter(Daten_1.CreateDateTime, Daten_1.predicted, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
plt.ylim((-500,100))


ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('TagValue_86', color=col3, fontsize=16)
ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))

ax4 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax4.set_ylabel('TagValue_71', color=col4, fontsize=16)
ax4.plot(Daten_4.CreateDateTime, Daten_4.TagValue, color=col4)
ax4.tick_params(axis='y', labelcolor=col4)
ax4.spines["right"].set_position(("axes", 1.2))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
ID_85_2021.plot('CreateDateTime','TagValue')
# Out:
# <AxesSubplot:xlabel='CreateDateTime'>

# %%
ID_86_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_086_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_133_138_2021=pd.read_csv("C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\ID_141_bis_146_2021.csv",parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_71_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_073_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

#data['predicted']=linreg.intercept_+np.dot(X,linreg.coef_.T) 

Daten_1=data
Daten_3=ID_86_2021
Daten_4=ID_71_2021
Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-09-06 08:05:00')&(Daten_1['CreateDateTime']<'2021-09-06 08:40:00')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2021-09-06 08:05:00')&(Daten_3['CreateDateTime']<'2021-09-06 08:40:00')]
Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2021-09-06 08:05:00')&(Daten_4['CreateDateTime']<'2021-09-06 08:40:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_51_2021', color=col1, fontsize=16)
ax.scatter(Daten_1.CreateDateTime, Daten_1.TagValue_51, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
plt.ylim((-500,100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_51_predicted', color=col2, fontsize=16)
ax2.scatter(Daten_1.CreateDateTime, Daten_1.predicted, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
plt.ylim((-500,100))


ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('TagValue_85', color=col3, fontsize=16)
ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))

ax4 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax4.set_ylabel('TagValue_133_138', color=col4, fontsize=16)
ax4.plot(Daten_4.CreateDateTime, Daten_4.TagValue, color=col4)
ax4.tick_params(axis='y', labelcolor=col4)
ax4.spines["right"].set_position(("axes", 1.2))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
ID_86_2021=pd.read_csv('C:\\2_Studium\\SS2022\\ADP\\AZO\\AZO\\2021\\TagID_086_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
Daten_1=data
Daten_3=ID_86_2021
Daten_4=ID_71_2021
Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2021-09-06 08:15:00')&(Daten_1['CreateDateTime']<'2021-09-06 08:20:00')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2021-09-06 08:15:00')&(Daten_3['CreateDateTime']<'2021-09-06 08:20:00')]
Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2021-09-06 08:15:00')&(Daten_4['CreateDateTime']<'2021-09-06 08:20:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_51_2021', color=col1, fontsize=16)
ax.scatter(Daten_1.CreateDateTime, Daten_1.TagValue_51, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
plt.ylim((-500,100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_51_predicted', color=col2, fontsize=16)
ax2.scatter(Daten_1.CreateDateTime, Daten_1.predicted, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
plt.ylim((-500,100))


ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('TagValue_85', color=col3, fontsize=16)
ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))

ax4 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax4.set_ylabel('TagValue_133_138', color=col4, fontsize=16)
ax4.plot(Daten_4.CreateDateTime, Daten_4.TagValue, color=col4)
ax4.tick_params(axis='y', labelcolor=col4)
ax4.spines["right"].set_position(("axes", 1.2))
