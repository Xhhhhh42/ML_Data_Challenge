# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import time
import datetime
from datetime import timedelta
import scipy.stats as stats

# %%
ID_51_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_051_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_52_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_052_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
ID_85_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_085_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_86_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_086_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_58_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_058_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_53_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_053_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
ID_133_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_133_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_134_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_134_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_135_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_135_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_136_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_136_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_137_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_137_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_138_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_138_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
ID_150_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_150_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_140_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_140_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_139_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_139_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
ID_141_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_141_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
ID_70_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_070_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
ID_13_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_013_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
ID_58_2020.plot('CreateDateTime','TagValue')
# Out:
# <AxesSubplot:xlabel='CreateDateTime'>

# %%
a_ID_13_2020=ID_13_2020[(ID_13_2020['CreateDateTime']>'2020-09-22 23:55:00')&(ID_13_2020['CreateDateTime']<'2020-09-23 14:05:00')]
a_ID_13_2020.plot('CreateDateTime','TagValue')
# Out:
# <AxesSubplot:xlabel='CreateDateTime'>

# %%
Daten_1=ID_51_2020
Daten_2=ID_52_2020


Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-09-22 13:58:00')&(Daten_1['CreateDateTime']<'2020-09-22 16:25:00')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2020-09-22 13:58:00')&(Daten_2['CreateDateTime']<'2020-09-22 16:25:00')]


fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_51_2020_', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_52_2020_', color=col2, fontsize=16)
ax2.plot(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
#plt.ylim((-1,10))

Daten_1=ID_51_2020
Daten_2=ID_52_2020


Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-09-22 15:05:00')&(Daten_1['CreateDateTime']<'2020-09-22 15:10:00')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2020-09-22 15:05:00')&(Daten_2['CreateDateTime']<'2020-09-22 15:10:00')]


fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_51_2020_', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_52_2020_', color=col2, fontsize=16)
ax2.plot(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
#plt.ylim((-1,10))

# %%
Daten_1=ID_13_2020
Daten_2=ID_52_2020
Daten_3=ID_85_2020
Daten_4=ID_70_2020

Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-09-22 00:58:00')&(Daten_1['CreateDateTime']<'2020-09-22 02:25:00')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2020-09-22 00:58:00')&(Daten_2['CreateDateTime']<'2020-09-22 02:25:00')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2020-09-22 00:58:00')&(Daten_3['CreateDateTime']<'2020-09-22 02:25:00')]
Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2020-09-22 00:58:00')&(Daten_4['CreateDateTime']<'2020-09-22 02:25:00')]


fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_13_2020_', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_52_2020_', color=col2, fontsize=16)
ax2.plot(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
#plt.ylim((-1,10))

ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('ID_85_2019_', color=col3, fontsize=16)
ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))



ax4 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax4.set_ylabel('ID_70_2020_', color=col4, fontsize=16)
ax4.plot(Daten_4.CreateDateTime, Daten_4.TagValue, color=col4)
ax4.tick_params(axis='y', labelcolor=col4)
ax4.spines["right"].set_position(("axes", 1.2))

# %%
Daten_1=ID_51_2020
Daten_2=ID_52_2020
Daten_3=ID_133_2020
Daten_4=ID_134_2020
Daten_5=ID_135_2020
Daten_6=ID_136_2020

Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-09-22 15:00:00')&(Daten_1['CreateDateTime']<'2020-09-22 15:10:00')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2020-09-22 15:00:00')&(Daten_2['CreateDateTime']<'2020-09-22 15:10:00')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2020-09-22 15:00:00')&(Daten_3['CreateDateTime']<'2020-09-22 15:10:00')]
Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2020-09-22 15:00:00')&(Daten_4['CreateDateTime']<'2020-09-22 15:10:00')]
Daten_5=Daten_5[(Daten_5['CreateDateTime']>'2020-09-22 15:00:00')&(Daten_5['CreateDateTime']<'2020-09-22 15:10:00')]
Daten_6=Daten_6[(Daten_6['CreateDateTime']>'2020-09-22 15:00:00')&(Daten_6['CreateDateTime']<'2020-09-22 15:10:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_51_2019_', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_52_2019_', color=col2, fontsize=16)
ax2.plot(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
#plt.ylim((-1,10))

ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('ID_133_2019_', color=col3, fontsize=16)
ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))

ax4 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax4.set_ylabel('ID_134_2020_', color=col4, fontsize=16)
ax4.plot(Daten_4.CreateDateTime, Daten_4.TagValue, color=col4)
ax4.tick_params(axis='y', labelcolor=col4)
ax4.spines["right"].set_position(("axes", 1.2))


#plt.ylim((-1,10))
ax5 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax5.set_ylabel('ID_140_2020_', color=col5, fontsize=16)
ax5.plot(Daten_5.CreateDateTime, Daten_5.TagValue, color=col5)
ax5.tick_params(axis='y', labelcolor=col5)
ax5.spines["right"].set_position(("axes", 1.3))


#plt.ylim((-1,10))

ax6 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax6.set_ylabel('ID_70_2020_', color=col6, fontsize=16)
ax6.plot(Daten_6.CreateDateTime, Daten_6.TagValue, color=col6)
ax6.tick_params(axis='y', labelcolor=col6)
ax6.spines["right"].set_position(("axes", 1.4))

# %%
ID_51_2019=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2019/TagID_051_2019.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_52_2019=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2019/TagID_052_2019.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_133_2019=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2019/TagID_133_2019.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 ID_51_2019=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2019/TagID_051_2019.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
#       2 ID_52_2019=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2019/TagID_052_2019.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
#       3 ID_133_2019=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2019/TagID_133_2019.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
#
# File D:\Anaconda\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %%
ID_133_2019=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2019/TagID_133_2019.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_134_2019=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2019/TagID_134_2019.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_135_2019=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2019/TagID_135_2019.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_136_2019=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2019/TagID_136_2019.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_137_2019=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2019/TagID_137_2019.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_138_2019=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2019/TagID_138_2019.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
FilterPeriode2019=ID_133_2019
FilterPeriode2019['TagValue']=FilterPeriode2019.CreateDateTime.diff(2).dt.total_seconds()
FilterPeriode2019=FilterPeriode2019[(FilterPeriode2019['TagValue']<1000)]
FilterPeriode2019.plot('CreateDateTime','TagValue',kind='scatter',figsize=(20, 8))

# %%
Daten_1=ID_51_2019
Daten_2=ID_52_2019
Daten_3=ID_133_2019
Daten_4=ID_134_2019
Daten_5=FilterPeriode2019
Daten_6=ID_139_2020

Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2019-01-02 14:58:00')&(Daten_1['CreateDateTime']<'2019-01-02 17:05:00')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2019-01-02 14:58:00')&(Daten_2['CreateDateTime']<'2019-01-02 17:05:00')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2019-01-02 14:58:00')&(Daten_3['CreateDateTime']<'2019-01-02 17:05:00')]
Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2019-01-02 14:58:00')&(Daten_4['CreateDateTime']<'2019-01-02 17:05:00')]
Daten_5=Daten_5[(Daten_5['CreateDateTime']>'2019-01-02 14:58:00')&(Daten_5['CreateDateTime']<'2019-01-02 17:05:00')]
Daten_6=Daten_6[(Daten_6['CreateDateTime']>'2020-09-22 14:58:00')&(Daten_6['CreateDateTime']<'2020-09-22 20:05:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_51_2019_', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_52_2019_', color=col2, fontsize=16)
ax2.plot(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
#plt.ylim((-1,10))

ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('ID_133_2019_', color=col3, fontsize=16)
ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))
plt.ylim((-1,3))

ax4 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax4.set_ylabel('ID_134_2020_', color=col4, fontsize=16)
ax4.plot(Daten_4.CreateDateTime, Daten_4.TagValue, color=col4)
ax4.tick_params(axis='y', labelcolor=col4)
ax4.spines["right"].set_position(("axes", 1.2))
plt.ylim((-1,3))

#plt.ylim((-1,10))
ax5 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax5.set_ylabel('ID_133_2020_FilterPeriode2020', color=col5, fontsize=16)
ax5.plot(Daten_5.CreateDateTime, Daten_5.TagValue, color=col5)
ax5.tick_params(axis='y', labelcolor=col5)
ax5.spines["right"].set_position(("axes", 1.3))


# plt.ylim((100,800))

# ax6 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax6.set_ylabel('ID_70_2020_', color=col6, fontsize=16)
# ax6.plot(Daten_6.CreateDateTime, Daten_6.TagValue, color=col6)
# ax6.tick_params(axis='y', labelcolor=col6)
# ax6.spines["right"].set_position(("axes", 1.4))

# %%
Daten_1=ID_51_2019
Daten_2=ID_52_2019
Daten_3=ID_133_2019
Daten_4=ID_134_2019
Daten_5=ID_135_2019
Daten_6=ID_136_2019
Daten_7=ID_137_2019
Daten_8=ID_138_2019

Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2019-01-02 15:51:00')&(Daten_1['CreateDateTime']<'2019-01-02 16:05:00')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2019-01-02 15:51:00')&(Daten_2['CreateDateTime']<'2019-01-02 16:05:00')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2019-01-02 15:51:00')&(Daten_3['CreateDateTime']<'2019-01-02 16:05:00')]
Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2019-01-02 15:51:00')&(Daten_4['CreateDateTime']<'2019-01-02 16:05:00')]
Daten_5=Daten_5[(Daten_5['CreateDateTime']>'2019-01-02 15:51:00')&(Daten_5['CreateDateTime']<'2019-01-02 16:05:00')]
Daten_6=Daten_6[(Daten_6['CreateDateTime']>'2019-01-02 15:51:00')&(Daten_6['CreateDateTime']<'2019-01-02 16:05:00')]
Daten_7=Daten_7[(Daten_7['CreateDateTime']>'2019-01-02 15:51:00')&(Daten_7['CreateDateTime']<'2019-01-02 16:05:00')]
Daten_8=Daten_8[(Daten_8['CreateDateTime']>'2019-01-02 15:51:00')&(Daten_8['CreateDateTime']<'2019-01-02 16:05:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'
col7='blue'
col8='yellow'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_51_2019_', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


# ax2 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax2.set_ylabel('ID_52_2019_', color=col2, fontsize=16)
# ax2.plot(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
# ax2.tick_params(axis='y', labelcolor=col2)
# #plt.ylim((-1,10))

ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('ID_133_2019_', color=col3, fontsize=16)
ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))
#plt.ylim((-1,3))

ax4 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax4.set_ylabel('ID_134_2019_', color=col4, fontsize=16)
ax4.plot(Daten_4.CreateDateTime, Daten_4.TagValue, color=col4)
ax4.tick_params(axis='y', labelcolor=col4)
ax4.spines["right"].set_position(("axes", 1.2))
#plt.ylim((-1,3))

#plt.ylim((-1,10))
ax5 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax5.set_ylabel('ID_135_2019_', color=col5, fontsize=16)
ax5.plot(Daten_5.CreateDateTime, Daten_5.TagValue, color=col5)
ax5.tick_params(axis='y', labelcolor=col5)
ax5.spines["right"].set_position(("axes", 1.3))


# plt.ylim((100,800))

ax6 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax6.set_ylabel('ID_136_2020_', color=col6, fontsize=16)
ax6.plot(Daten_6.CreateDateTime, Daten_6.TagValue, color=col6)
ax6.tick_params(axis='y', labelcolor=col6)
ax6.spines["right"].set_position(("axes", 1.4))

ax7 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax7.set_ylabel('ID_137_2020_', color=col7, fontsize=16)
ax7.plot(Daten_7.CreateDateTime, Daten_7.TagValue, color=col7)
ax7.tick_params(axis='y', labelcolor=col7)
ax7.spines["right"].set_position(("axes", 1.5))

ax8 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax8.set_ylabel('ID_138_2020_', color=col8, fontsize=16)
ax8.plot(Daten_8.CreateDateTime, Daten_8.TagValue, color=col8)
ax8.tick_params(axis='y', labelcolor=col8)
ax8.spines["right"].set_position(("axes", 1.6))

# %%
Daten_1=ID_51_2019
Daten_2=ID_52_2019
Daten_3=ID_133_2019
Daten_4=ID_134_2019
Daten_5=ID_135_2019
Daten_6=ID_136_2019
Daten_7=ID_137_2019
Daten_8=ID_138_2019

Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2019-05-02 15:51:00')&(Daten_1['CreateDateTime']<'2019-05-02 16:05:00')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2019-05-02 15:51:00')&(Daten_2['CreateDateTime']<'2019-05-02 16:05:00')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2019-05-02 15:51:00')&(Daten_3['CreateDateTime']<'2019-05-02 16:05:00')]
Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2019-05-02 15:51:00')&(Daten_4['CreateDateTime']<'2019-05-02 16:05:00')]
Daten_5=Daten_5[(Daten_5['CreateDateTime']>'2019-05-02 15:51:00')&(Daten_5['CreateDateTime']<'2019-05-02 16:05:00')]
Daten_6=Daten_6[(Daten_6['CreateDateTime']>'2019-05-02 15:51:00')&(Daten_6['CreateDateTime']<'2019-05-02 16:05:00')]
Daten_7=Daten_7[(Daten_7['CreateDateTime']>'2019-05-02 15:51:00')&(Daten_7['CreateDateTime']<'2019-05-02 16:05:00')]
Daten_8=Daten_8[(Daten_8['CreateDateTime']>'2019-05-02 15:51:00')&(Daten_8['CreateDateTime']<'2019-05-02 16:05:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'
col7='blue'
col8='yellow'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_51_2019_', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


# ax2 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax2.set_ylabel('ID_52_2019_', color=col2, fontsize=16)
# ax2.plot(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
# ax2.tick_params(axis='y', labelcolor=col2)
# #plt.ylim((-1,10))

ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('ID_133_2019_', color=col3, fontsize=16)
ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))
#plt.ylim((-1,3))

ax4 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax4.set_ylabel('ID_134_2019_', color=col4, fontsize=16)
ax4.plot(Daten_4.CreateDateTime, Daten_4.TagValue, color=col4)
ax4.tick_params(axis='y', labelcolor=col4)
ax4.spines["right"].set_position(("axes", 1.2))
#plt.ylim((-1,3))

#plt.ylim((-1,10))
ax5 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax5.set_ylabel('ID_135_2019_', color=col5, fontsize=16)
ax5.plot(Daten_5.CreateDateTime, Daten_5.TagValue, color=col5)
ax5.tick_params(axis='y', labelcolor=col5)
ax5.spines["right"].set_position(("axes", 1.3))


# plt.ylim((100,800))

ax6 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax6.set_ylabel('ID_136_2020_', color=col6, fontsize=16)
ax6.plot(Daten_6.CreateDateTime, Daten_6.TagValue, color=col6)
ax6.tick_params(axis='y', labelcolor=col6)
ax6.spines["right"].set_position(("axes", 1.4))

ax7 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax7.set_ylabel('ID_137_2020_', color=col7, fontsize=16)
ax7.plot(Daten_7.CreateDateTime, Daten_7.TagValue, color=col7)
ax7.tick_params(axis='y', labelcolor=col7)
ax7.spines["right"].set_position(("axes", 1.5))

ax8 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax8.set_ylabel('ID_138_2020_', color=col8, fontsize=16)
ax8.plot(Daten_8.CreateDateTime, Daten_8.TagValue, color=col8)
ax8.tick_params(axis='y', labelcolor=col8)
ax8.spines["right"].set_position(("axes", 1.6))

# %%
ID_51_2019.plot('CreateDateTime','TagValue')

# %%
Daten_3

# %%
Daten_1=ID_13_2020
Daten_2=ID_52_2020
Daten_3=ID_70_2020
Daten_4=ID_139_2020
Daten_5=ID_140_2020

Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-09-21 19:55:00')&(Daten_1['CreateDateTime']<'2020-09-22 00:25:00')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2020-09-21 19:55:00')&(Daten_2['CreateDateTime']<'2020-09-22 00:25:00')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2020-09-21 19:55:00')&(Daten_3['CreateDateTime']<'2020-09-22 00:25:00')]
Daten_4=Daten_4[(Daten_4['CreateDateTime']>'2020-09-21 19:55:00')&(Daten_4['CreateDateTime']<'2020-09-22 00:25:00')]
Daten_5=Daten_5[(Daten_5['CreateDateTime']>'2020-09-21 19:55:00')&(Daten_5['CreateDateTime']<'2020-09-22 00:25:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_13_2020', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


# ax2 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax2.set_ylabel('ID_52_2020', color=col2, fontsize=16)
# ax2.plot(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
# ax2.tick_params(axis='y', labelcolor=col2)
# #plt.ylim((-1,10))

ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('ID_70_2020', color='black', fontsize=16)
ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue, color='black')
ax3.tick_params(axis='y', labelcolor='black')
ax3.spines["right"].set_position(("axes", 1.1))

# #plt.ylim((-1,10))
# ax4 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax4.set_ylabel('ID_139_2020', color='green', fontsize=16)
# ax4.plot(Daten_4.CreateDateTime, Daten_4.TagValue, color='green')
# ax4.tick_params(axis='y', labelcolor='green')
# ax4.spines["right"].set_position(("axes", 1.2))

# #plt.ylim((-1,10))

# ax5 = ax.twinx()
# #ax2 = ax.twiny()
# #add second line to plot
# ax5.set_ylabel('ID_140_2020', color='magenta', fontsize=16)
# ax5.plot(Daten_5.CreateDateTime, Daten_5.TagValue, color='magenta')
# ax5.tick_params(axis='y', labelcolor='magenta')
# ax5.spines["right"].set_position(("axes", 1.3))

# #plt.ylim((-1,10))

# %%
ID_70_2020.plot('CreateDateTime','TagValue')
# Out:
# <AxesSubplot:xlabel='CreateDateTime'>

# %%
ID_133_2020
# Out:
#                 CreateDateTime  TagValue  TagId
# 0      2020-02-06 13:05:56.982       0.0    133
# 1      2020-02-06 13:06:28.636       1.0    133
# 2      2020-02-06 13:06:28.839       0.0    133
# 3      2020-02-06 13:09:30.945       1.0    133
# 4      2020-02-06 13:09:31.353       0.0    133
# ...                        ...       ...    ...
# 108214 2020-12-26 22:24:01.854       0.0    133
# 108215 2020-12-26 22:27:03.901       1.0    133
# 108216 2020-12-26 22:27:04.308       0.0    133
# 108217 2020-12-26 22:30:06.159       1.0    133
# 108218 2020-12-26 22:30:06.554       0.0    133
#
# [108219 rows x 3 columns]

# %%
FilterPeriode2020=ID_133_2020
FilterPeriode2020['TagValue']=FilterPeriode2020.CreateDateTime.diff(2).dt.total_seconds()

# %%
FilterPeriode2020.plot('CreateDateTime','TagValue')
# Out:
# <AxesSubplot:xlabel='CreateDateTime'>

# %%
FilterPeriode2020=FilterPeriode2020[(FilterPeriode2020['TagValue']<1000)]
FilterPeriode2020.plot('CreateDateTime','TagValue')
# Out:
# <AxesSubplot:xlabel='CreateDateTime'>

# %%
Daten_1=FilterPeriode2020

#Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-11-01 14:00:00')&(Daten_1['CreateDateTime']<'2020-12-01 21:02:00')]

# %%
Daten_1.plot('CreateDateTime','TagValue',kind='scatter',figsize=(20, 8))
# Out:
# <AxesSubplot:xlabel='CreateDateTime', ylabel='TagValue'>

# %%
Daten_1['TagValue'].value_counts(ascending=True,normalize=True)
# Out:
# 31.857     0.000009
# 78.818     0.000009
# 79.028     0.000009
# 248.566    0.000009
# 290.454    0.000009
#              ...
# 182.384    0.003781
# 182.395    0.003837
# 182.405    0.003911
# 182.394    0.004005
# 182.409    0.004014
# Name: TagValue, Length: 19548, dtype: float64

# %%
ID_133_2019=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2019/TagID_133_2019.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

FilterPeriode2019=ID_133_2019
FilterPeriode2019['TagValue']=FilterPeriode2019.CreateDateTime.diff(2).dt.total_seconds()
FilterPeriode2019=FilterPeriode2019[(FilterPeriode2019['TagValue']<1000)]
FilterPeriode2019.plot('CreateDateTime','TagValue',kind='scatter',figsize=(20, 8))

# %%
ID_133_2018=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2018/TagID_133_2018.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

FilterPeriode2019=ID_133_2018
FilterPeriode2019['TagValue']=FilterPeriode2019.CreateDateTime.diff(2).dt.total_seconds()
FilterPeriode2019=FilterPeriode2019[(FilterPeriode2019['TagValue']<1000)]
FilterPeriode2019.plot('CreateDateTime','TagValue',kind='scatter',figsize=(20, 8))

# %%
ID_133_2021=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2021/TagID_133_2021.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

FilterPeriode2019=ID_133_2021
FilterPeriode2019['TagValue']=FilterPeriode2019.CreateDateTime.diff(2).dt.total_seconds()
FilterPeriode2019=FilterPeriode2019[(FilterPeriode2019['TagValue']<1000)]
FilterPeriode2019.plot('CreateDateTime','TagValue',kind='scatter',figsize=(20, 8))
