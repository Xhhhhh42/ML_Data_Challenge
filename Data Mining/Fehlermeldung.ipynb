# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import time
import datetime
from datetime import timedelta
import scipy.stats as stats

# %%
ID_51_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_051_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_53_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_053_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_52_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_052_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_123_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_123_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
ID_55_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_055_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
ID_161_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_161_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
ID_100_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_100_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
ID_80_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_080_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
ID_62_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_062_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
ID_72_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_072_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
ID_44_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_044_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_45_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_045_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_46_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_046_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
ID_25_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_025_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
ID_118_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_118_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_119_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_119_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_120_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_120_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_121_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_121_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_122_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_122_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_123_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_123_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_124_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_124_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
ID_10_2020=pd.read_csv('//srv-mla/MLA_ADP2022/Tags_2020/TagID_010_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
Daten_1=ID_51_2020
Daten_2=ID_52_2020
Daten_3=ID_45_2020

# Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-09-29 14:58:00')&(Daten_1['CreateDateTime']<'2020-09-29 15:25:00')]
# Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2020-09-29 14:58:00')&(Daten_2['CreateDateTime']<'2020-09-29 15:25:00')]
# Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2020-09-29 14:58:00')&(Daten_3['CreateDateTime']<'2020-09-29 15:25:00')]

Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-09-22 12:58:00')&(Daten_1['CreateDateTime']<'2020-09-22 18:25:00')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2020-09-22 12:58:00')&(Daten_2['CreateDateTime']<'2020-09-22 18:25:00')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2020-09-22 12:58:00')&(Daten_3['CreateDateTime']<'2020-09-22 18:25:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_51_2020_', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_52_2020_', color=col2, fontsize=16)
ax2.plot(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
#plt.ylim((-1,10))


ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('ID_133_2019_', color=col3, fontsize=16)
ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))

# %%
Daten_1=ID_51_2020
Daten_2=ID_52_2020
Daten_3=ID_45_2020

# Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-09-29 14:58:00')&(Daten_1['CreateDateTime']<'2020-09-29 15:25:00')]
# Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2020-09-29 14:58:00')&(Daten_2['CreateDateTime']<'2020-09-29 15:25:00')]
# Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2020-09-29 14:58:00')&(Daten_3['CreateDateTime']<'2020-09-29 15:25:00')]

Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-03-01 15:27:13')&(Daten_1['CreateDateTime']<'2020-03-01 19:52:41')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2020-03-01 15:27:13')&(Daten_2['CreateDateTime']<'2020-03-01 19:52:41')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2020-03-01 15:27:13')&(Daten_3['CreateDateTime']<'2020-03-01 19:52:41')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_51_2020_', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_52_2020_', color=col2, fontsize=16)
ax2.plot(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
#plt.ylim((-1,10))


ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('ID_133_2019_', color=col3, fontsize=16)
ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))

# %%
Daten_1=ID_51_2020
Daten_2=ID_52_2020
Daten_3=ID_119_2020

# Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-09-29 14:58:00')&(Daten_1['CreateDateTime']<'2020-09-29 15:25:00')]
# Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2020-09-29 14:58:00')&(Daten_2['CreateDateTime']<'2020-09-29 15:25:00')]
# Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2020-09-29 14:58:00')&(Daten_3['CreateDateTime']<'2020-09-29 15:25:00')]

Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-06-26 16:27:13')&(Daten_1['CreateDateTime']<'2020-06-26 16:52:41')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2020-06-26 16:27:13')&(Daten_2['CreateDateTime']<'2020-06-26 16:52:41')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2020-06-26 16:27:13')&(Daten_3['CreateDateTime']<'2020-06-26 16:52:41')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_51_2020_', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_52_2020_', color=col2, fontsize=16)
ax2.plot(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
#plt.ylim((-1,10))


ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('ID_133_2019_', color=col3, fontsize=16)
ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))

# %%
Daten_1=ID_51_2020
Daten_2=ID_45_2020
Daten_3=ID_119_2020

# Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-09-29 14:58:00')&(Daten_1['CreateDateTime']<'2020-09-29 15:25:00')]
# Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2020-09-29 14:58:00')&(Daten_2['CreateDateTime']<'2020-09-29 15:25:00')]
# Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2020-09-29 14:58:00')&(Daten_3['CreateDateTime']<'2020-09-29 15:25:00')]

Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-06-22 16:27:13')&(Daten_1['CreateDateTime']<'2020-07-28 16:52:41')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2020-06-22 16:27:13')&(Daten_2['CreateDateTime']<'2020-07-28 16:52:41')]
Daten_3=Daten_3[(Daten_3['CreateDateTime']>'2020-06-22 16:27:13')&(Daten_3['CreateDateTime']<'2020-07-28 16:52:41')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
col3='black'
col4='green'
col5='magenta'
col6='cyan'

ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_51_2020_', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_52_2020_', color=col2, fontsize=16)
ax2.plot(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
#plt.ylim((-1,10))


ax3 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax3.set_ylabel('ID_133_2019_', color=col3, fontsize=16)
ax3.plot(Daten_3.CreateDateTime, Daten_3.TagValue, color=col3)
ax3.tick_params(axis='y', labelcolor=col3)
ax3.spines["right"].set_position(("axes", 1.1))

# %%
ID_45_2020.plot('CreateDateTime','TagValue',figsize=(20, 8))
ID_119_2020.plot('CreateDateTime','TagValue',figsize=(20, 8))
ID_123_2020.plot('CreateDateTime','TagValue',figsize=(20, 8))
ID_51_2020.plot('CreateDateTime','TagValue',figsize=(20, 8))
# Out:
# <AxesSubplot:xlabel='CreateDateTime'>

# %%
ID_123_2020
# Out:
#             CreateDateTime  TagValue  TagId
# 0  2020-02-06 13:05:56.982       0.0    123
# 1  2020-03-04 00:52:27.655       1.0    123
# 2  2020-03-23 07:14:56.314       1.0    123
# 3  2020-04-28 14:24:15.771       1.0    123
# 4  2020-04-28 15:23:24.252       1.0    123
# 5  2020-05-01 23:55:20.224       0.0    123
# 6  2020-05-01 23:55:26.793       1.0    123
# 7  2020-05-06 06:14:31.633       0.0    123
# 8  2020-07-20 10:25:39.729       0.0    123
# 9  2020-07-23 14:10:11.552       0.0    123
# 10 2020-07-27 18:20:14.030       1.0    123
# 11 2020-07-27 18:20:22.788       0.0    123
# 12 2020-08-10 12:37:11.642       1.0    123
# 13 2020-08-10 12:37:37.275       0.0    123
# 14 2020-08-12 19:11:08.589       0.0    123
# 15 2020-09-21 09:35:13.073       0.0    123
# 16 2020-10-27 12:39:30.747       0.0    123
# 17 2020-12-15 14:55:19.393       0.0    123
