# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import time
import datetime
from datetime import timedelta
import scipy.stats as stats

# %%
ID_46_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_046_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_120_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_120_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_124_2020=pd.read_csv(r'D:\留德十年\TUD\ADP\Data\2020/TagID_124_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')

# %%
ID_46_2020.plot('CreateDateTime','TagValue')
# Out:
# <AxesSubplot:xlabel='CreateDateTime'>

# %%
ID_120_2020.plot('CreateDateTime','TagValue')
# Out:
# <AxesSubplot:xlabel='CreateDateTime'>

# %%
ID_124_2020.plot('CreateDateTime','TagValue')
# Out:
# <AxesSubplot:xlabel='CreateDateTime'>
