# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import time
import datetime
from datetime import timedelta
import scipy.stats as stats

# %%
ID_159_2020=pd.read_csv('D:\留德十年\TUD\ADP\Data\TagID_159_2019/TagID_159_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_57_2020=pd.read_csv('D:\留德十年\TUD\ADP\Data\TagID_159_2019/TagID_057_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_57_2020
# Out:
#                   CreateDateTime  TagValue  TagId
# 0        2020-02-06 13:05:56.982 -1.822917     57
# 1        2020-02-06 13:05:58.643 -1.765046     57
# 2        2020-02-06 13:05:58.847 -1.822917     57
# 3        2020-02-06 13:06:00.073 -1.765046     57
# 4        2020-02-06 13:06:00.277 -1.822917     57
# ...                          ...       ...    ...
# 36953055 2020-12-31 23:59:57.772 -3.327546     57
# 36953056 2020-12-31 23:59:58.179 -3.298611     57
# 36953057 2020-12-31 23:59:58.388 -3.327546     57
# 36953058 2020-12-31 23:59:59.205 -3.298611     57
# 36953059 2020-12-31 23:59:59.405 -3.327546     57
#
# [36953060 rows x 3 columns]

# %%
ID_159_2020
# Out:
#               CreateDateTime  TagValue  TagId
# 0    2020-02-06 13:05:56.982       0.0    159
# 1    2020-03-23 07:14:56.304       0.0    159
# 2    2020-03-24 15:27:28.793       1.0    159
# 3    2020-03-24 15:27:28.998       0.0    159
# 4    2020-03-24 15:28:14.036       1.0    159
# ...                      ...       ...    ...
# 1469 2020-09-23 21:07:17.074       0.0    159
# 1470 2020-09-23 21:20:04.362       1.0    159
# 1471 2020-09-23 21:20:04.583       0.0    159
# 1472 2020-10-27 12:39:30.735       0.0    159
# 1473 2020-12-15 14:55:19.382       0.0    159
#
# [1474 rows x 3 columns]

# %%
#ID_159_2018['TagValue']=ID_159_2018.CreateDateTime.diff(2).dt.total_seconds()

# %%
#ID_159_2020['TagValue']=ID_159_2020.CreateDateTime.diff(2).dt.total_seconds()

# %%
ID_159_2020.plot('CreateDateTime','TagValue',kind='scatter')
# Out:
# <AxesSubplot:xlabel='CreateDateTime', ylabel='TagValue'>

# %%
ID_159_2018=ID_159_2018[(ID_159_2018['TagValue']<100000)]
ID_159_2018.plot('CreateDateTime','TagValue',kind='scatter')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ZHILUN~1\AppData\Local\Temp/ipykernel_2764/542393663.py in <module>
# ----> 1 ID_159_2018=ID_159_2018[(ID_159_2018['TagValue']<100000)]
#       2 ID_159_2018.plot('CreateDateTime','TagValue',kind='scatter')
#
# NameError: name 'ID_159_2018' is not defined

# %%
ID_57_2020=pd.read_csv('TagID_057_2020.csv',dtype= {'CreateDateTime': str, 'TagValue': np.float64, 'TagId': np.int32},parse_dates=['CreateDateTime'],index_col='Unnamed: 0')
ID_57_2020
# Out:
#                   CreateDateTime  TagValue  TagId
# 0        2020-02-06 13:05:56.982 -1.822917     57
# 1        2020-02-06 13:05:58.643 -1.765046     57
# 2        2020-02-06 13:05:58.847 -1.822917     57
# 3        2020-02-06 13:06:00.073 -1.765046     57
# 4        2020-02-06 13:06:00.277 -1.822917     57
# ...                          ...       ...    ...
# 36953055 2020-12-31 23:59:57.772 -3.327546     57
# 36953056 2020-12-31 23:59:58.179 -3.298611     57
# 36953057 2020-12-31 23:59:58.388 -3.327546     57
# 36953058 2020-12-31 23:59:59.205 -3.298611     57
# 36953059 2020-12-31 23:59:59.405 -3.327546     57
#
# [36953060 rows x 3 columns]

# %%
ID_57_2020.plot('CreateDateTime','TagValue')
# Out:
# <AxesSubplot:xlabel='CreateDateTime'>

# %%
ID_57_2020['TagValue']=ID_57_2020.TagValue.diff(1)

# %%
ID_57_2020
# Out:
#                   CreateDateTime  TagValue  TagId
# 0        2020-02-06 13:05:56.982       NaN     57
# 1        2020-02-06 13:05:58.643  0.057871     57
# 2        2020-02-06 13:05:58.847 -0.057871     57
# 3        2020-02-06 13:06:00.073  0.057871     57
# 4        2020-02-06 13:06:00.277 -0.057871     57
# ...                          ...       ...    ...
# 36953055 2020-12-31 23:59:57.772 -0.028935     57
# 36953056 2020-12-31 23:59:58.179  0.028935     57
# 36953057 2020-12-31 23:59:58.388 -0.028935     57
# 36953058 2020-12-31 23:59:59.205  0.028935     57
# 36953059 2020-12-31 23:59:59.405 -0.028935     57
#
# [36953060 rows x 3 columns]

# %%
ID_159_2020
# Out:
#               CreateDateTime     TagValue  TagId
# 0    2020-02-06 13:05:56.982          NaN    159
# 1    2020-03-23 07:14:56.304          NaN    159
# 2    2020-03-24 15:27:28.793  4069291.811    159
# 3    2020-03-24 15:27:28.998   115952.694    159
# 4    2020-03-24 15:28:14.036       45.243    159
# ...                      ...          ...    ...
# 1469 2020-09-23 21:07:17.074       45.241    159
# 1470 2020-09-23 21:20:04.362      767.689    159
# 1471 2020-09-23 21:20:04.583      767.509    159
# 1472 2020-10-27 12:39:30.735  2906366.373    159
# 1473 2020-12-15 14:55:19.382  7148114.799    159
#
# [1474 rows x 3 columns]

# %%
ID_159_2020.plot('CreateDateTime','TagValue')
# Out:
# <AxesSubplot:xlabel='CreateDateTime'>

# %%
ID_57_2020.plot('CreateDateTime','TagValue')
# Out:
# <AxesSubplot:xlabel='CreateDateTime'>

# %%
ID_159_2020.dtypes
# Out:
# CreateDateTime    datetime64[ns]
# TagValue                 float64
# TagId                      int32
# dtype: object

# %%
Daten_1=ID_57_2020
Daten_2=ID_159_2020

Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2020-03-26 06:06:00')&(Daten_1['CreateDateTime']<'2020-03-26 08:06:00')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2020-03-26 06:06:00')&(Daten_2['CreateDateTime']<'2020-03-26 08:06:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_57_2020_DifDruAbs_8_3_mbar_Diff', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_159_2020_Filterabreinigung_S', color=col2, fontsize=16)
ax2.scatter(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
#plt.ylim((-1,10))

# %%
Daten_12=Daten_1.set_index('CreateDateTime').join(Daten_2.set_index('CreateDateTime'),lsuffix='_l', rsuffix='_r',how='outer')
#ID_58_141_2018=ID_58_141_2018.interpolate()
df = Daten_12.fillna(0)
#Daten_12=Daten_12.fillna(method="bfill")
#Daten_12['TagValue_0']=0

# %%
#df = Daten_12.fillna(0)
#df=Daten_12.dropna()
df
# Out:
#                          TagValue_l  TagId_l  TagValue_r  TagId_r
# CreateDateTime
# 2020-03-26 06:06:00.537   -0.028935     57.0         0.0      0.0
# 2020-03-26 06:06:00.742    0.028935     57.0         0.0      0.0
# 2020-03-26 06:06:01.357    0.028935     57.0         0.0      0.0
# 2020-03-26 06:06:01.561   -0.028935     57.0         0.0      0.0
# 2020-03-26 06:06:04.011    0.028935     57.0         0.0      0.0
# ...                             ...      ...         ...      ...
# 2020-03-26 08:05:56.551   -0.028935     57.0         0.0      0.0
# 2020-03-26 08:05:58.601    0.028935     57.0         0.0      0.0
# 2020-03-26 08:05:59.423   -0.028935     57.0         0.0      0.0
# 2020-03-26 08:05:59.627    0.028935     57.0         0.0      0.0
# 2020-03-26 08:05:59.830   -0.028935     57.0         0.0      0.0
#
# [14658 rows x 4 columns]

# %%
r, p = stats.pointbiserialr(df.dropna()['TagValue_l'], df.dropna()['TagValue_r'])
df2=df[['TagValue_l','TagValue_r']]
f,ax=plt.subplots(figsize=(7,3))
df2.rolling(window=150,center=True).median().plot(ax=ax)
# Out:
# <AxesSubplot:xlabel='CreateDateTime'>

# %%
r
# Out:
# -0.24553687999714705

# %%
stats.pointbiserialr(Daten_1['TagValue'],Daten_2['TagValue'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ZHILUN~1\AppData\Local\Temp/ipykernel_32992/2176335928.py in <module>
# ----> 1 stats.pointbiserialr(Daten_1['TagValue'],Daten_2['TagValue'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in pointbiserialr(x, y)
#    4612
#    4613     """
# -> 4614     rpb, prob = pearsonr(x, y)
#    4615     return PointbiserialrResult(rpb, prob)
#    4616
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    4011     n = len(x)
#    4012     if n != len(y):
# -> 4013         raise ValueError('x and y must have the same length.')
#    4014
#    4015     if n < 2:
#
# ValueError: x and y must have the same length.

# %%
ID_159_2018
# Out:
#               CreateDateTime  TagValue  TagId
# 0    2018-10-09 18:07:43.914       0.0    159
# 1    2018-10-10 10:24:50.690       0.0    159
# 2    2018-10-10 10:25:19.174       0.0    159
# 3    2018-10-10 10:38:57.331       0.0    159
# 4    2018-10-10 10:46:23.305       0.0    159
# ...                      ...       ...    ...
# 2985 2018-10-28 22:24:48.383       1.0    159
# 2986 2018-10-28 22:24:49.391       0.0    159
# 2987 2018-10-28 23:09:03.807       1.0    159
# 2988 2018-10-28 23:09:04.814       0.0    159
# 2989 2018-11-22 16:52:24.461       0.0    159
#
# [2990 rows x 3 columns]

# %%
Daten_1=ID_57_2018
Daten_2=ID_159_2018

Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2018-10-17 06:50:25')&(Daten_1['CreateDateTime']<'2018-10-17 07:15:40')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2018-10-17 06:50:25')&(Daten_2['CreateDateTime']<'2018-10-17 07:15:40')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_57_2018_DifDruAbs_8_3_mbar', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_59_2018_Filterabreinigung_S', color=col2, fontsize=16)
ax2.scatter(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
#plt.ylim((-1,10))

# %%
Daten_1=ID_57_2018
Daten_2=ID_159_2018

Daten_1=Daten_1[(Daten_1['CreateDateTime']>'2018-10-17 07:45:25')&(Daten_1['CreateDateTime']<'2018-10-17 07:55:40')]
Daten_2=Daten_2[(Daten_2['CreateDateTime']>'2018-10-17 07:45:25')&(Daten_2['CreateDateTime']<'2018-10-17 07:55:40')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_57_2018_DifDruAbs_8_3_mbar', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_59_2018_Filterabreinigung_DifZeit_S', color=col2, fontsize=16)
ax2.scatter(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
#plt.ylim((-1,10))

# %%
Daten_1=ID_57_2018[(ID_57_2018['CreateDateTime']>'2018-10-20 02:17:00')&(ID_57_2018['CreateDateTime']<'2018-10-20 02:19:00')]
Daten_2=ID_159_2018[(ID_159_2018['CreateDateTime']>'2018-10-20 02:17:00')&(ID_159_2018['CreateDateTime']<'2018-10-20 02:19:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_57_2018_DifDruAbs_8_3_mbar', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
#plt.ylim((0, 100))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_59_2018_Filterabreinigung_DifZeit_S', color=col2, fontsize=16)
ax2.scatter(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
#plt.ylim((-1,10))

# %%
Daten_1=ID_57_2018[(ID_57_2018['CreateDateTime']>'2018-10-20 07:06:00')&(ID_57_2018['CreateDateTime']<'2018-10-20 07:10:00')]
Daten_2=ID_159_2018[(ID_159_2018['CreateDateTime']>'2018-10-20 07:06:00')&(ID_159_2018['CreateDateTime']<'2018-10-20 07:10:00')]

fig, ax = plt.subplots(figsize=(20, 8))
col1 = 'steelblue'
col2 = 'red'
ax.set_xlabel('Datum und Uhrzeit', fontsize=14)
ax.set_ylabel('ID_57_2018_DifDruAbs_8_3_mbar', color=col1, fontsize=16)
ax.plot(Daten_1.CreateDateTime, Daten_1.TagValue, color=col1)
ax.tick_params(axis='y', labelcolor=col1)
plt.ylim((-5, 0))

#add y-axis label


#define second y-axis that shares x-axis with current plot


ax2 = ax.twinx()
#ax2 = ax.twiny()
#add second line to plot
ax2.set_ylabel('ID_59_2018_Filterabreinigung_DifZeit_S', color=col2, fontsize=16)
ax2.scatter(Daten_2.CreateDateTime, Daten_2.TagValue, color=col2)
ax2.tick_params(axis='y', labelcolor=col2)
plt.ylim((-1,1700))
# Out:
# (-1.0, 1700.0)

# %%
Daten_2
# Out:
#              CreateDateTime  TagValue  TagId
# 869 2018-10-20 07:07:42.071  1572.887    159
# 870 2018-10-20 07:07:43.077  1572.887    159

# %%
#pd.set_option('display.max_rows', None)
Daten_3=Daten_1[(Daten_1['CreateDateTime']>'2018-03-02 06:15:46')&(Daten_1['CreateDateTime']<'2018-03-02 06:15:48')]
Daten_3
# Out:
# Empty DataFrame
# Columns: [CreateDateTime, TagValue, TagId]
# Index: []

# %%
Daten_3=Daten_1[(Daten_1['CreateDateTime']>'2018-03-02 06:16:31')&(Daten_1['CreateDateTime']<'2018-03-02 06:16:33')]
Daten_3
# Out:
# Empty DataFrame
# Columns: [CreateDateTime, TagValue, TagId]
# Index: []
